# %%
import random
import numpy as np
from keras.models import Sequential
from keras.layers.core import Dense, Activation
from keras.optimizers import Adam
import pandas as pd

random.seed(0)

class DQNAgent():
    def __init__(self, env, epsilon=1.0, alpha=0.5, gamma=0.9, time = 30000):
        self.env = env
        self.action_size = self.env.action_space.n
        self.state_size = env.observation_space
        self.memory = deque(maxlen=2000) # Record past experiences- [(state, action, reward, next_state, done)...]
        self.epsilon = epsilon   # Random exploration factor
        self.alpha = alpha       # Learning factor
        self.gamma = gamma       # Discount factor- closer to 1 learns well into distant future
        self.epsilon_min = 0.01
        self.epsilon_decay = 0.99
        self.learning = True
        self.model = self._build_model()
        
        self.time = time 
        self.time_left = time # Epsilon Decay
        self.small_decrement = (0.4 * epsilon) / (0.3 * self.time_left) # reduce epsilon
        print('HELLO')
    
    # Build Neural Net
    def _build_model(self):
#         print(type(self.state_size))
        model = Sequential()
        model.add(Dense(32, input_shape = (2,), kernel_initializer='random_uniform', activation='relu'))
        model.add(Dense(16, activation='relu'))
        model.add(Dense(self.action_size, activation='softmax'))
        model.compile(loss='binary_crossentropy', optimizer=Adam(lr=self.alpha))
        
        return model
       
#     # Remember function that stores states, actions, rewards, and done to memory
#     def remember(self, state, action, reward, next_state, done):
#         self.memory.append([state, action, reward, next_state, done])

    def choose_action(self, state):
        """
        Choose which action to take, based on the observation. 
        Uses greedy epsilon for exploration/exploitation.
        """

        # if random number > epsilon, act 'rationally'. otherwise, choose random action
        
        if np.random.rand() <= self.epsilon:
#             print(np.random.rand())
#             print(self.epsilon)
#             print('random')
#             print('-------')
            
            action = random.randrange(self.action_size)
#             print('random: ' + str(action))

            
        else:
#             print('logic')

            action_value = self.model.predict(state)
#             print(action_value)
#             print(action_value)
#             print(action_value)
#             print('-------')
            action = np.argmax(action_value[0])
#             print(action)
        
        self.update_parameters()
        return action
        
    def update_parameters(self):
        """
        Update epsilon and alpha after each action
        Set them to 0 if not learning
        """
#         print(self.time_left)
        if self.time_left > 0.9 * self.time:
            self.epsilon -= self.small_decrement
        elif self.time_left > 0.7 * self.time:
            self.epsilon -= self.small_decrement
        elif self.time_left > 0.5 * self.time:
            self.epsilon -= self.small_decrement
#             print('0.5')
        elif self.time_left > 0.3 * self.time:
#             print('0.2')
            self.epsilon -= self.small_decrement
        elif self.time_left > 0.1 * self.time:
            self.epsilon -= self.small_decrement
#         elif self.time_left < 0.05 * self.time:
#             self.epsilon = 0.000
#             self.learning = False

#         print(self.time_left)
        #         print(self.time)
        self.time_left -= 1       


    def learn(self, state, action, reward, next_state, done):
        
        
        
#         minibatch = random.sample(self.memory, batch_size)
#         print(minibatch)
        
        target = reward
#         print('STATE: ' + str(state))
#             print('next_state: ' + str(state))

#         print('target: ' + str(target))

        if not done:
            target = reward + self.gamma * np.amax(self.model.predict(next_state)[0])

#         print('target: ' + str(target))


#         print('action: ' + str(action))
#             print(self.model.predict(next_state))
#         print(np.amax(self.model.predict(next_state)[0]))

        target_f = self.model.predict(state)
#         print(target_f)
#         print('target_f: ' + str(target_f))


        target_f[0][action] = target
#         print('target_f: ' + str(target_f))
#             print('target_f: ' + str(target_f))
#         print('-------')

        self.model.fit(state, target_f, epochs=1, verbose=0)
        
        
#             print(self.time)
#         print(self.epsilon)

    def get_optimal_strategy(self):
        index = []
        for x in range(0,21):
            for y in range(1,11):
                index.append((x,y))

        df = pd.DataFrame(index = index, columns = ['Stand', 'Hit'])

        for ind in index:
            outcome = self.model.predict([np.array([ind])], batch_size=1)
            df.loc[ind, 'Stand'] = outcome[0][0]
            df.loc[ind, 'Hit'] = outcome[0][1]


        df['Optimal'] = df.apply(lambda x : 'Hit' if x['Hit'] >= x['Stand'] else 'Stand', axis=1)
        df.to_csv('optimal_policy.csv')
        return df
# Out:
# Using TensorFlow backend.

# %%
import gym
from env import NFLPlaycallingEnv
# env = gym.make('Blackjack-v0')
# env.seed(0)
env = NFLPlaycallingEnv()
# env = wrappers.Monitor(env, './runs', False, True)
import matplotlib.pyplot as plt
from collections import deque
import time

start_time = time.time()

# print(agent.model)

num_rounds = 100 # Payout calculated over num_rounds
num_samples = 50 # num_rounds simulated over num_samples

agent = DQNAgent(env=env, epsilon=1.0, alpha=0.001, gamma=0.1, time=7500)

average_payouts = []

state = env.reset()
state = np.reshape(state[0:2], [1,2])
for sample in range(num_samples):
    round = 1
    total_payout = 0 # store total payout per sample
    while round <= num_rounds:
        action = agent.choose_action(state)
        next_state, payout, done, _ = env.step(action)
        next_state = np.reshape(next_state[0:2], [1,2])

        
        total_payout += payout    
#         if agent.learning:
        agent.learn(state, action, payout, next_state, done)
        
        state = next_state
        state = np.reshape(state[0:2], [1,2])
        
        if done:
            state = env.reset() # Environment deals new cards to player and dealer
            state = np.reshape(state[0:2], [1,2])
            round += 1

    average_payouts.append(total_payout)

    if sample % 1 == 0:
        print('Done with sample: ' + str(sample) + str("   --- %s seconds ---" % (time.time() - start_time)))
        print(agent.epsilon)

print(agent.get_optimal_strategy())

# Plot payout per 1000 episodes for each value of 'sample'

plt.plot(average_payouts)           
plt.xlabel('num_samples')
plt.ylabel('payout after 1000 rounds')
plt.show()      
    
print ("Average payout after {} rounds is {}".format(num_rounds, sum(average_payouts)/(num_samples)))
# Out:
# HELLO
# state: action FIELD_GOAL, obs: (10, 2, 10, 1, 0, 0), done: True, reward: -6.3
# state: action FIELD_GOAL, obs: (10, 2, 10, 1, 0, 0), done: True, reward: -6.3
# state: action PUNT, obs: (69.0, 2, 10, 1, 0, 0), done: True, reward: -2.1700000000000004
# state: action QB_SNEAK, obs: (37.0, 3, 10, 0, 0, 0), done: False, reward: 0.0
# state: action QB_SNEAK, obs: (45.0, 2, 2.0, 0, 0, 0), done: False, reward: 0.0
# state: action RUN, obs: (48.0, 3, 10, 0, 0, 0), done: False, reward: 0.0
# state: action QB_SNEAK, obs: (51.0, 2, 7.0, 0, 0, 0), done: False, reward: 0.0
# state: action PASS, obs: (59.0, 3, 10, 0, 0, 0), done: False, reward: 0.0
# state: action QB_SNEAK, obs: (83.0, 3, 10, 0, 0, 0), done: False, reward: 0.0
# state: action PUNT, obs: (83.0, 2, 10, 1, 0, 0), done: True, reward: -1.1900000000000004
# state: action PUNT, obs: (79.0, 2, 10, 1, 0, 0), done: True, reward: -1.4699999999999998
# state: action QB_SNEAK, obs: (21.0, 2, 9.0, 0, 0, 0), done: False, reward: 0.0
# state: action PASS, obs: (45.0, 3, 10, 0, 0, 0), done: False, reward: 0.0
# state: action QB_SNEAK, obs: (51.0, 2, 4.0, 0, 0, 0), done: False, reward: 0.0
# state: action PASS, obs: (51.0, 1, 4.0, 0, 0, 0), done: False, reward: 0.0
# state: action QB_SNEAK, obs: (59.0, 3, 10, 0, 0, 0), done: False, reward: 0.0
# state: action RUN, obs: (80.0, 3, 10, 0, 0, 0), done: False, reward: 0.0
# state: action FIELD_GOAL, obs: (80.0, 2, 10, 0, 0, 1), done: True, reward: 3.0
# state: action PUNT, obs: (64.0, 2, 10, 1, 0, 0), done: True, reward: -2.52
# state: action PUNT, obs: (80.0, 2, 10, 1, 0, 0), done: True, reward: -1.3999999999999997
# state: action PASS, obs: (31.0, 3, 10, 0, 0, 0), done: False, reward: 0.0
# state: action FIELD_GOAL, obs: (21.0, 2, 10, 1, 0, 0), done: True, reward: -5.53
# state: action PASS, obs: (28.0, 2, 2.0, 0, 0, 0), done: False, reward: 0.0
# state: action QB_SNEAK, obs: (31.0, 3, 10, 0, 0, 0), done: False, reward: 0.0
# state: action QB_SNEAK, obs: (40.0, 2, 1.0, 0, 0, 0), done: False, reward: 0.0
# state: action PASS, obs: (40.0, 1, 1.0, 0, 0, 0), done: False, reward: 0.0
# state: action PUNT, obs: (80.0, 0, 1.0, 1, 0, 0), done: True, reward: -1.3999999999999997
# state: action RUN, obs: (27.0, 2, 3.0, 0, 0, 0), done: False, reward: 0.0
# state: action FIELD_GOAL, obs: (17.0, 1, 3.0, 1, 0, 0), done: True, reward: -5.81
# state: action QB_SNEAK, obs: (32.0, 3, 10, 0, 0, 0), done: False, reward: 0.0
# state: action FIELD_GOAL, obs: (22.0, 2, 10, 1, 0, 0), done: True, reward: -5.46
# state: action PUNT, obs: (64.0, 2, 10, 1, 0, 0), done: True, reward: -2.52
# state: action PASS, obs: (27.0, 2, 3.0, 0, 0, 0), done: False, reward: 0.0
# state: action PUNT, obs: (68.0, 1, 3.0, 1, 0, 0), done: True, reward: -2.2399999999999998
# state: action PUNT, obs: (70.0, 2, 10, 1, 0, 0), done: True, reward: -2.1000000000000005
# state: action QB_SNEAK, obs: (25.0, 2, 5.0, 0, 0, 0), done: False, reward: 0.0
# state: action PUNT, obs: (80.0, 1, 5.0, 1, 0, 0), done: True, reward: -1.3999999999999997
# state: action QB_SNEAK, obs: (27.0, 2, 3.0, 0, 0, 0), done: False, reward: 0.0
# state: action QB_SNEAK, obs: (30.0, 3, 10, 0, 0, 0), done: False, reward: 0.0
# state: action RUN, obs: (28.0, 2, 12.0, 0, 0, 0), done: False, reward: 0.0
# state: action QB_SNEAK, obs: (33.0, 1, 7.0, 0, 0, 0), done: False, reward: 0.0
# state: action RUN, obs: (32.0, 0, 8.0, 0, 0, 0), done: True, reward: -4.76
# state: action RUN, obs: (30.0, 3, 10, 0, 0, 0), done: False, reward: 0.0
# state: action PASS, obs: (46.0, 3, 10, 0, 0, 0), done: False, reward: 0.0
# state: action PUNT, obs: (91.0, 2, 10, 1, 0, 0), done: True, reward: -0.6299999999999998
# state: action PUNT, obs: (64.0, 2, 10, 1, 0, 0), done: True, reward: -2.52
# state: action RUN, obs: (29.0, 2, 1.0, 0, 0, 0), done: False, reward: 0.0
# state: action PUNT, obs: (85.0, 1, 1.0, 1, 0, 0), done: True, reward: -1.0500000000000003
# state: action FIELD_GOAL, obs: (10, 2, 10, 1, 0, 0), done: True, reward: -6.3
# state: action FIELD_GOAL, obs: (10, 2, 10, 1, 0, 0), done: True, reward: -6.3
# state: action QB_SNEAK, obs: (21.0, 2, 9.0, 0, 0, 0), done: False, reward: 0.0
# state: action PUNT, obs: (59.0, 1, 9.0, 1, 0, 0), done: True, reward: -2.87
# state: action PUNT, obs: (72.0, 2, 10, 1, 0, 0), done: True, reward: -1.9600000000000002
# state: action RUN, obs: (21.0, 2, 9.0, 0, 0, 0), done: False, reward: 0.0
# state: action QB_SNEAK, obs: (23.0, 1, 7.0, 0, 0, 0), done: False, reward: 0.0
# state: action RUN, obs: (25.0, 0, 5.0, 0, 0, 0), done: True, reward: -5.25
# state: action RUN, obs: (22.0, 2, 8.0, 0, 0, 0), done: False, reward: 0.0
# state: action PASS, obs: (22.0, 1, 8.0, 0, 0, 0), done: False, reward: 0.0
# state: action RUN, obs: (31.0, 3, 10, 0, 0, 0), done: False, reward: 0.0
# state: action RUN, obs: (29.0, 2, 12.0, 0, 0, 0), done: False, reward: 0.0
# state: action PASS, obs: (36.0, 1, 5.0, 0, 0, 0), done: False, reward: 0.0
# state: action PUNT, obs: (85.0, 0, 5.0, 1, 0, 0), done: True, reward: -1.0500000000000003
# state: action PASS, obs: (13.0, 2, 17.0, 0, 0, 0), done: False, reward: 0.0
# state: action RUN, obs: (17.0, 1, 13.0, 0, 0, 0), done: False, reward: 0.0
# state: action PUNT, obs: (55.0, 0, 13.0, 1, 0, 0), done: True, reward: -3.1499999999999995
# state: action PASS, obs: (20.0, 2, 10.0, 0, 0, 0), done: False, reward: 0.0
# state: action PASS, obs: (14.0, 1, 16.0, 0, 0, 0), done: False, reward: 0.0
# state: action PASS, obs: (14.0, 0, 16.0, 0, 0, 0), done: True, reward: -6.02
# state: action RUN, obs: (25.0, 2, 5.0, 0, 0, 0), done: False, reward: 0.0
# state: action FIELD_GOAL, obs: (15.0, 1, 5.0, 1, 0, 0), done: True, reward: -5.95
# state: action PASS, obs: (53.0, 3, 10, 0, 0, 0), done: False, reward: 0.0
# state: action PASS, obs: (59.0, 2, 4.0, 0, 0, 0), done: False, reward: 0.0
# state: action PUNT, obs: (84.0, 1, 4.0, 1, 0, 0), done: True, reward: -1.12
# state: action QB_SNEAK, obs: (21.0, 2, 9.0, 0, 0, 0), done: False, reward: 0.0
# state: action PASS, obs: (30.0, 3, 10, 0, 0, 0), done: False, reward: 0.0
# state: action QB_SNEAK, obs: (35.0, 2, 5.0, 0, 0, 0), done: False, reward: 0.0
# state: action PASS, obs: (32.0, 1, 8.0, 0, 0, 0), done: False, reward: 0.0
# state: action FIELD_GOAL, obs: (22.0, 0, 8.0, 1, 0, 0), done: True, reward: -5.46
# state: action PASS, obs: (31.0, 3, 10, 0, 0, 0), done: False, reward: 0.0
# state: action FIELD_GOAL, obs: (21.0, 2, 10, 1, 0, 0), done: True, reward: -5.53
# state: action QB_SNEAK, obs: (33.0, 3, 10, 0, 0, 0), done: False, reward: 0.0
# state: action FIELD_GOAL, obs: (23.0, 2, 10, 1, 0, 0), done: True, reward: -5.390000000000001
# state: action PUNT, obs: (61.0, 2, 10, 1, 0, 0), done: True, reward: -2.73
# state: action RUN, obs: (40.0, 3, 10, 0, 0, 0), done: False, reward: 0.0
# state: action PASS, obs: (55.0, 3, 10, 0, 0, 0), done: False, reward: 0.0
# state: action RUN, obs: (64.0, 2, 1.0, 0, 0, 0), done: False, reward: 0.0
# state: action QB_SNEAK, obs: (70.0, 3, 10, 0, 0, 0), done: False, reward: 0.0
# state: action PASS, obs: (77.0, 2, 3.0, 0, 0, 0), done: False, reward: 0.0
# state: action FIELD_GOAL, obs: (77.0, 1, 3.0, 0, 0, 1), done: True, reward: 3.0
# state: action PASS, obs: (25.0, 2, 5.0, 0, 0, 0), done: False, reward: 0.0
# state: action FIELD_GOAL, obs: (15.0, 1, 5.0, 1, 0, 0), done: True, reward: -5.95
# state: action PUNT, obs: (80.0, 2, 10, 1, 0, 0), done: True, reward: -1.3999999999999997
# state: action QB_SNEAK, obs: (25.0, 2, 5.0, 0, 0, 0), done: False, reward: 0.0
# state: action QB_SNEAK, obs: (27.0, 1, 3.0, 0, 0, 0), done: False, reward: 0.0
# state: action PASS, obs: (31.0, 3, 10, 0, 0, 0), done: False, reward: 0.0
# state: action PASS, obs: (31.0, 2, 10.0, 0, 0, 0), done: False, reward: 0.0
# state: action PASS, obs: (37.0, 1, 4.0, 0, 0, 0), done: False, reward: 0.0
# state: action RUN, obs: (38.0, 0, 3.0, 0, 0, 0), done: True, reward: -4.34
# state: action FIELD_GOAL, obs: (10, 2, 10, 1, 0, 0), done: True, reward: -6.3
# state: action QB_SNEAK, obs: (28.0, 2, 2.0, 0, 0, 0), done: False, reward: 0.0
# state: action PUNT, obs: (89.0, 1, 2.0, 1, 0, 0), done: True, reward: -0.7699999999999999
# state: action PUNT, obs: (60.0, 2, 10, 1, 0, 0), done: True, reward: -2.8000000000000003
# state: action QB_SNEAK, obs: (25.0, 2, 5.0, 0, 0, 0), done: False, reward: 0.0
# state: action FIELD_GOAL, obs: (15.0, 1, 5.0, 1, 0, 0), done: True, reward: -5.95
# state: action PASS, obs: (8.0, 2, 22.0, 0, 0, 0), done: False, reward: 0.0
# state: action RUN, obs: (13.0, 1, 17.0, 0, 0, 0), done: False, reward: 0.0
# state: action RUN, obs: (14.0, 0, 16.0, 0, 0, 0), done: True, reward: -6.02
# state: action FIELD_GOAL, obs: (10, 2, 10, 1, 0, 0), done: True, reward: -6.3
# state: action PUNT, obs: (79.0, 2, 10, 1, 0, 0), done: True, reward: -1.4699999999999998
# state: action PASS, obs: (23.0, 2, 7.0, 0, 0, 0), done: False, reward: 0.0
# state: action PUNT, obs: (70.0, 1, 7.0, 1, 0, 0), done: True, reward: -2.1000000000000005
# state: action PASS, obs: (20.0, 2, 10.0, 0, 0, 0), done: False, reward: 0.0
# state: action PASS, obs: (20.0, 1, 10.0, 0, 0, 0), done: False, reward: 0.0
# state: action RUN, obs: (23.0, 0, 7.0, 0, 0, 0), done: True, reward: -5.390000000000001
# state: action FIELD_GOAL, obs: (10, 2, 10, 1, 0, 0), done: True, reward: -6.3
# state: action PUNT, obs: (75.0, 2, 10, 1, 0, 0), done: True, reward: -1.75
# state: action PASS, obs: (25.0, 2, 5.0, 0, 0, 0), done: False, reward: 0.0
# state: action QB_SNEAK, obs: (36.0, 3, 10, 0, 0, 0), done: False, reward: 0.0
# state: action PASS, obs: (51.0, 3, 10, 0, 0, 0), done: False, reward: 0.0
# state: action FIELD_GOAL, obs: (51.0, 2, 10, 1, 0, 0), done: True, reward: -3.4299999999999997
# state: action PASS, obs: (36.0, 3, 10, 0, 0, 0), done: False, reward: 0.0
# state: action RUN, obs: (71.0, 3, 10, 0, 0, 0), done: False, reward: 0.0
# state: action FIELD_GOAL, obs: (71.0, 2, 10, 1, 0, 0), done: True, reward: -2.0300000000000002
# state: action FIELD_GOAL, obs: (10, 2, 10, 1, 0, 0), done: True, reward: -6.3
# state: action RUN, obs: (16.0, 2, 14.0, 0, 0, 0), done: False, reward: 0.0
# state: action PASS, obs: (16.0, 1, 14.0, 1, 0, 0), done: True, reward: -5.88
# state: action PUNT, obs: (72.0, 2, 10, 1, 0, 0), done: True, reward: -1.9600000000000002
# state: action RUN, obs: (20.0, 2, 10.0, 0, 0, 0), done: False, reward: 0.0
# state: action RUN, obs: (30.0, 3, 10, 0, 0, 0), done: False, reward: 0.0
# state: action QB_SNEAK, obs: (39.0, 2, 1.0, 0, 0, 0), done: False, reward: 0.0
# state: action RUN, obs: (39.0, 1, 1.0, 0, 0, 0), done: False, reward: 0.0
# state: action FIELD_GOAL, obs: (39.0, 0, 1.0, 1, 0, 0), done: True, reward: -4.27
# state: action PASS, obs: (20.0, 2, 10.0, 0, 0, 0), done: False, reward: 0.0
# state: action FIELD_GOAL, obs: (10.0, 1, 10.0, 1, 0, 0), done: True, reward: -6.3
# state: action PASS, obs: (38.0, 3, 10, 0, 0, 0), done: False, reward: 0.0
# state: action RUN, obs: (43.0, 2, 5.0, 0, 0, 0), done: False, reward: 0.0
# state: action QB_SNEAK, obs: (45.0, 1, 3.0, 0, 0, 0), done: False, reward: 0.0
# state: action RUN, obs: (46.0, 0, 2.0, 0, 0, 0), done: True, reward: -3.7800000000000002
# state: action PASS, obs: (15.0, 2, 15.0, 0, 0, 0), done: False, reward: 0.0
# state: action RUN, obs: (20.0, 1, 10.0, 0, 0, 0), done: False, reward: 0.0
# state: action PUNT, obs: (65.0, 0, 10.0, 1, 0, 0), done: True, reward: -2.4499999999999997
# state: action QB_SNEAK, obs: (35.0, 3, 10, 0, 0, 0), done: False, reward: 0.0
# state: action PASS, obs: (52.0, 3, 10, 0, 0, 0), done: False, reward: 0.0
# state: action PUNT, obs: (90.0, 2, 10, 1, 0, 0), done: True, reward: -0.6999999999999998
# state: action FIELD_GOAL, obs: (10, 2, 10, 1, 0, 0), done: True, reward: -6.3
# state: action QB_SNEAK, obs: (32.0, 3, 10, 0, 0, 0), done: False, reward: 0.0
# state: action RUN, obs: (33.0, 2, 9.0, 0, 0, 0), done: False, reward: 0.0
# state: action PUNT, obs: (77.0, 1, 9.0, 1, 0, 0), done: True, reward: -1.6099999999999999
# state: action RUN, obs: (20.0, 2, 10.0, 0, 0, 0), done: False, reward: 0.0
# state: action QB_SNEAK, obs: (24.0, 1, 6.0, 0, 0, 0), done: False, reward: 0.0
# state: action QB_SNEAK, obs: (36.0, 3, 10, 0, 0, 0), done: False, reward: 0.0
# state: action QB_SNEAK, obs: (48.0, 3, 10, 0, 0, 0), done: False, reward: 0.0
# state: action PASS, obs: (43.0, 2, 15.0, 0, 0, 0), done: False, reward: 0.0
# state: action PASS, obs: (43.0, 1, 15.0, 0, 0, 0), done: False, reward: 0.0
# state: action PUNT, obs: (83.0, 0, 15.0, 1, 0, 0), done: True, reward: -1.1900000000000004
# state: action FIELD_GOAL, obs: (10, 2, 10, 1, 0, 0), done: True, reward: -6.3
# state: action RUN, obs: (22.0, 2, 8.0, 0, 0, 0), done: False, reward: 0.0
# state: action FIELD_GOAL, obs: (12.0, 1, 8.0, 1, 0, 0), done: True, reward: -6.16
# state: action PASS, obs: (20.0, 2, 10.0, 0, 0, 0), done: False, reward: 0.0
# state: action PUNT, obs: (74.0, 1, 10.0, 1, 0, 0), done: True, reward: -1.82
# state: action QB_SNEAK, obs: (25.0, 2, 5.0, 0, 0, 0), done: False, reward: 0.0
# state: action QB_SNEAK, obs: (28.0, 1, 2.0, 0, 0, 0), done: False, reward: 0.0
# state: action PASS, obs: (28.0, 0, 2.0, 0, 0, 0), done: True, reward: -5.04
# state: action FIELD_GOAL, obs: (10, 2, 10, 1, 0, 0), done: True, reward: -6.3
# state: action QB_SNEAK, obs: (22.0, 2, 8.0, 0, 0, 0), done: False, reward: 0.0
# state: action PASS, obs: (31.0, 3, 10, 0, 0, 0), done: False, reward: 0.0
# state: action FIELD_GOAL, obs: (21.0, 2, 10, 1, 0, 0), done: True, reward: -5.53
# state: action QB_SNEAK, obs: (29.0, 2, 1.0, 0, 0, 0), done: False, reward: 0.0
# state: action RUN, obs: (42.0, 3, 10, 0, 0, 0), done: False, reward: 0.0
# state: action PUNT, obs: (84.0, 2, 10, 1, 0, 0), done: True, reward: -1.12
# state: action PASS, obs: (18.0, 2, 12.0, 0, 0, 0), done: False, reward: 0.0
# state: action PASS, obs: (18.0, 1, 12.0, 0, 0, 0), done: False, reward: 0.0
# state: action RUN, obs: (17.0, 0, 13.0, 0, 0, 0), done: True, reward: -5.81
# state: action PASS, obs: (20.0, 2, 10.0, 0, 0, 0), done: False, reward: 0.0
# state: action PUNT, obs: (70.0, 1, 10.0, 1, 0, 0), done: True, reward: -2.1000000000000005
# state: action FIELD_GOAL, obs: (10, 2, 10, 1, 0, 0), done: True, reward: -6.3
# state: action PUNT, obs: (74.0, 2, 10, 1, 0, 0), done: True, reward: -1.82
# state: action RUN, obs: (23.0, 2, 7.0, 0, 0, 0), done: False, reward: 0.0
# state: action QB_SNEAK, obs: (26.0, 1, 4.0, 0, 0, 0), done: False, reward: 0.0
# state: action QB_SNEAK, obs: (33.0, 3, 10, 0, 0, 0), done: False, reward: 0.0
# state: action RUN, obs: (36.0, 2, 7.0, 0, 0, 0), done: False, reward: 0.0
# state: action QB_SNEAK, obs: (38.0, 1, 5.0, 0, 0, 0), done: False, reward: 0.0
# state: action PASS, obs: (60.0, 3, 10, 0, 0, 0), done: False, reward: 0.0
# state: action FIELD_GOAL, obs: (60.0, 2, 10, 1, 0, 0), done: True, reward: -2.8000000000000003
# state: action RUN, obs: (20.0, 2, 10.0, 0, 0, 0), done: False, reward: 0.0
# state: action FIELD_GOAL, obs: (10.0, 1, 10.0, 1, 0, 0), done: True, reward: -6.3
# state: action PASS, obs: (100, 2, 10, 0, 1, 0), done: True, reward: 7.0
# state: action RUN, obs: (24.0, 2, 6.0, 0, 0, 0), done: False, reward: 0.0
# state: action PASS, obs: (24.0, 1, 6.0, 0, 0, 0), done: False, reward: 0.0
# state: action FIELD_GOAL, obs: (14.0, 0, 6.0, 1, 0, 0), done: True, reward: -6.02
# state: action RUN, obs: (20.0, 2, 10.0, 0, 0, 0), done: False, reward: 0.0
# state: action PUNT, obs: (97.0, 1, 10.0, 1, 0, 0), done: True, reward: -0.2100000000000002
# state: action RUN, obs: (24.0, 2, 6.0, 0, 0, 0), done: False, reward: 0.0
# state: action FIELD_GOAL, obs: (14.0, 1, 6.0, 1, 0, 0), done: True, reward: -6.02
# state: action FIELD_GOAL, obs: (10, 2, 10, 1, 0, 0), done: True, reward: -6.3
# state: action QB_SNEAK, obs: (31.0, 3, 10, 0, 0, 0), done: False, reward: 0.0
# state: action FIELD_GOAL, obs: (21.0, 2, 10, 1, 0, 0), done: True, reward: -5.53
# state: action RUN, obs: (24.0, 2, 6.0, 0, 0, 0), done: False, reward: 0.0
# state: action RUN, obs: (20.0, 1, 10.0, 0, 0, 0), done: False, reward: 0.0
# state: action QB_SNEAK, obs: (30.0, 3, 10, 0, 0, 0), done: False, reward: 0.0
# state: action PASS, obs: (36.0, 2, 4.0, 0, 0, 0), done: False, reward: 0.0
# state: action QB_SNEAK, obs: (44.0, 3, 10, 0, 0, 0), done: False, reward: 0.0
# state: action RUN, obs: (53.0, 2, 1.0, 0, 0, 0), done: False, reward: 0.0
# state: action PUNT, obs: (87.0, 1, 1.0, 1, 0, 0), done: True, reward: -0.91
# state: action FIELD_GOAL, obs: (10, 2, 10, 1, 0, 0), done: True, reward: -6.3
# state: action PASS, obs: (26.0, 2, 4.0, 0, 0, 0), done: False, reward: 0.0
# state: action PASS, obs: (24.0, 1, 6.0, 0, 0, 0), done: False, reward: 0.0
# state: action RUN, obs: (22.0, 0, 8.0, 0, 0, 0), done: True, reward: -5.46
# state: action PASS, obs: (33.0, 3, 10, 0, 0, 0), done: False, reward: 0.0
# state: action FIELD_GOAL, obs: (23.0, 2, 10, 1, 0, 0), done: True, reward: -5.390000000000001
# state: action RUN, obs: (27.0, 2, 3.0, 0, 0, 0), done: False, reward: 0.0
# state: action FIELD_GOAL, obs: (17.0, 1, 3.0, 1, 0, 0), done: True, reward: -5.81
# state: action PUNT, obs: (67.0, 2, 10, 1, 0, 0), done: True, reward: -2.3099999999999996
# state: action PUNT, obs: (70.0, 2, 10, 1, 0, 0), done: True, reward: -2.1000000000000005
# state: action PUNT, obs: (57.0, 2, 10, 1, 0, 0), done: True, reward: -3.0100000000000002
# state: action PUNT, obs: (75.0, 2, 10, 1, 0, 0), done: True, reward: -1.75
# state: action PASS, obs: (32.0, 3, 10, 0, 0, 0), done: False, reward: 0.0
# state: action RUN, obs: (34.0, 2, 8.0, 0, 0, 0), done: False, reward: 0.0
# state: action PUNT, obs: (80.0, 1, 8.0, 1, 0, 0), done: True, reward: -1.3999999999999997
# state: action FIELD_GOAL, obs: (10, 2, 10, 1, 0, 0), done: True, reward: -6.3
# state: action FIELD_GOAL, obs: (10, 2, 10, 1, 0, 0), done: True, reward: -6.3
# state: action RUN, obs: (29.0, 2, 1.0, 0, 0, 0), done: False, reward: 0.0
# state: action PASS, obs: (38.0, 3, 10, 0, 0, 0), done: False, reward: 0.0
# state: action PASS, obs: (50.0, 3, 10, 0, 0, 0), done: False, reward: 0.0
# state: action QB_SNEAK, obs: (57.0, 2, 3.0, 0, 0, 0), done: False, reward: 0.0
# state: action QB_SNEAK, obs: (60.0, 3, 10, 0, 0, 0), done: False, reward: 0.0
# state: action FIELD_GOAL, obs: (60.0, 2, 10, 1, 0, 0), done: True, reward: -2.8000000000000003
# state: action QB_SNEAK, obs: (29.0, 2, 1.0, 0, 0, 0), done: False, reward: 0.0
# state: action FIELD_GOAL, obs: (19.0, 1, 1.0, 1, 0, 0), done: True, reward: -5.67
# state: action PASS, obs: (20.0, 2, 10.0, 0, 0, 0), done: False, reward: 0.0
# state: action RUN, obs: (21.0, 1, 9.0, 0, 0, 0), done: False, reward: 0.0
# state: action QB_SNEAK, obs: (22.0, 0, 8.0, 0, 0, 0), done: True, reward: -5.46
# state: action PASS, obs: (25.0, 2, 5.0, 0, 0, 0), done: False, reward: 0.0
# state: action RUN, obs: (28.0, 1, 2.0, 0, 0, 0), done: False, reward: 0.0
# state: action PUNT, obs: (80.0, 0, 2.0, 1, 0, 0), done: True, reward: -1.3999999999999997
# state: action RUN, obs: (28.0, 2, 2.0, 0, 0, 0), done: False, reward: 0.0
# state: action QB_SNEAK, obs: (33.0, 3, 10, 0, 0, 0), done: False, reward: 0.0
# state: action PASS, obs: (41.0, 2, 2.0, 0, 0, 0), done: False, reward: 0.0
# state: action FIELD_GOAL, obs: (31.0, 1, 2.0, 1, 0, 0), done: True, reward: -4.83
# state: action PASS, obs: (25.0, 2, 5.0, 0, 0, 0), done: False, reward: 0.0
# state: action RUN, obs: (21.0, 1, 9.0, 0, 0, 0), done: False, reward: 0.0
# state: action PUNT, obs: (72.0, 0, 9.0, 1, 0, 0), done: True, reward: -1.9600000000000002
# state: action QB_SNEAK, obs: (21.0, 2, 9.0, 0, 0, 0), done: False, reward: 0.0
# state: action PUNT, obs: (72.0, 1, 9.0, 1, 0, 0), done: True, reward: -1.9600000000000002
# Done with sample: 0   --- 92.66067814826965 seconds ---
# 0.9566222222222089
# state: action RUN, obs: (22.0, 2, 8.0, 0, 0, 0), done: False, reward: 0.0
# state: action FIELD_GOAL, obs: (12.0, 1, 8.0, 1, 0, 0), done: True, reward: -6.16
# state: action PASS, obs: (28.0, 2, 2.0, 0, 0, 0), done: False, reward: 0.0
# state: action FIELD_GOAL, obs: (18.0, 1, 2.0, 1, 0, 0), done: True, reward: -5.74
# state: action QB_SNEAK, obs: (28.0, 2, 2.0, 0, 0, 0), done: False, reward: 0.0
# state: action PUNT, obs: (71.0, 1, 2.0, 1, 0, 0), done: True, reward: -2.0300000000000002
# state: action RUN, obs: (38.0, 3, 10, 0, 0, 0), done: False, reward: 0.0
# state: action FIELD_GOAL, obs: (28.0, 2, 10, 1, 0, 0), done: True, reward: -5.04
# state: action PASS, obs: (26.0, 2, 4.0, 0, 0, 0), done: False, reward: 0.0
# state: action RUN, obs: (24.0, 1, 6.0, 0, 0, 0), done: False, reward: 0.0
# state: action FIELD_GOAL, obs: (14.0, 0, 6.0, 1, 0, 0), done: True, reward: -6.02
# state: action RUN, obs: (23.0, 2, 7.0, 0, 0, 0), done: False, reward: 0.0
# state: action PASS, obs: (75.0, 3, 10, 0, 0, 0), done: False, reward: 0.0
# state: action PASS, obs: (80.0, 2, 5.0, 0, 0, 0), done: False, reward: 0.0
# state: action PASS, obs: (100, 1, 5.0, 0, 1, 0), done: True, reward: 7.0
# state: action PUNT, obs: (71.0, 2, 10, 1, 0, 0), done: True, reward: -2.0300000000000002
# state: action RUN, obs: (21.0, 2, 9.0, 0, 0, 0), done: False, reward: 0.0
# state: action PUNT, obs: (74.0, 1, 9.0, 1, 0, 0), done: True, reward: -1.82
# state: action FIELD_GOAL, obs: (10, 2, 10, 1, 0, 0), done: True, reward: -6.3
# state: action PASS, obs: (20.0, 2, 10.0, 0, 0, 0), done: False, reward: 0.0
# state: action PUNT, obs: (68.0, 1, 10.0, 1, 0, 0), done: True, reward: -2.2399999999999998
# state: action PASS, obs: (52.0, 3, 10, 0, 0, 0), done: False, reward: 0.0
# state: action FIELD_GOAL, obs: (52.0, 2, 10, 1, 0, 0), done: True, reward: -3.36
# state: action FIELD_GOAL, obs: (10, 2, 10, 1, 0, 0), done: True, reward: -6.3
# state: action PASS, obs: (34.0, 3, 10, 0, 0, 0), done: False, reward: 0.0
# state: action FIELD_GOAL, obs: (24.0, 2, 10, 1, 0, 0), done: True, reward: -5.32
# state: action PASS, obs: (25.0, 2, 5.0, 0, 0, 0), done: False, reward: 0.0
# state: action QB_SNEAK, obs: (33.0, 3, 10, 0, 0, 0), done: False, reward: 0.0
# state: action PASS, obs: (33.0, 2, 10.0, 0, 0, 0), done: False, reward: 0.0
# state: action PASS, obs: (33.0, 1, 10.0, 0, 0, 0), done: False, reward: 0.0
# state: action PASS, obs: (33.0, 0, 10.0, 0, 0, 0), done: True, reward: -4.6899999999999995
# state: action RUN, obs: (16.0, 2, 14.0, 0, 0, 0), done: False, reward: 0.0
# state: action RUN, obs: (24.0, 1, 6.0, 0, 0, 0), done: False, reward: 0.0
# state: action PASS, obs: (31.0, 3, 10, 0, 0, 0), done: False, reward: 0.0
# state: action RUN, obs: (32.0, 2, 9.0, 0, 0, 0), done: False, reward: 0.0
# state: action RUN, obs: (37.0, 1, 4.0, 0, 0, 0), done: False, reward: 0.0
# state: action PASS, obs: (49.0, 3, 10, 0, 0, 0), done: False, reward: 0.0
# state: action QB_SNEAK, obs: (53.0, 2, 6.0, 0, 0, 0), done: False, reward: 0.0
# state: action PASS, obs: (84.0, 3, 10, 0, 0, 0), done: False, reward: 0.0
# state: action PASS, obs: (84.0, 2, 10.0, 0, 0, 0), done: False, reward: 0.0
# state: action RUN, obs: (84.0, 1, 10.0, 0, 0, 0), done: False, reward: 0.0
# state: action PASS, obs: (86.0, 0, 8.0, 0, 0, 0), done: True, reward: -0.9800000000000001
# state: action QB_SNEAK, obs: (22.0, 2, 8.0, 0, 0, 0), done: False, reward: 0.0
# state: action RUN, obs: (24.0, 1, 6.0, 0, 0, 0), done: False, reward: 0.0
# state: action FIELD_GOAL, obs: (14.0, 0, 6.0, 1, 0, 0), done: True, reward: -6.02
# state: action QB_SNEAK, obs: (35.0, 3, 10, 0, 0, 0), done: False, reward: 0.0
# state: action PUNT, obs: (85.0, 2, 10, 1, 0, 0), done: True, reward: -1.0500000000000003
# state: action RUN, obs: (24.0, 2, 6.0, 0, 0, 0), done: False, reward: 0.0
# state: action PASS, obs: (24.0, 1, 6.0, 0, 0, 0), done: False, reward: 0.0
# state: action PUNT, obs: (68.0, 0, 6.0, 1, 0, 0), done: True, reward: -2.2399999999999998
# state: action FIELD_GOAL, obs: (10, 2, 10, 1, 0, 0), done: True, reward: -6.3
# state: action RUN, obs: (27.0, 2, 3.0, 0, 0, 0), done: False, reward: 0.0
# state: action QB_SNEAK, obs: (34.0, 3, 10, 0, 0, 0), done: False, reward: 0.0
# state: action RUN, obs: (41.0, 2, 3.0, 0, 0, 0), done: False, reward: 0.0
# state: action QB_SNEAK, obs: (46.0, 3, 10, 0, 0, 0), done: False, reward: 0.0
# state: action PASS, obs: (64.0, 3, 10, 0, 0, 0), done: False, reward: 0.0
# state: action PUNT, obs: (82.0, 2, 10, 1, 0, 0), done: True, reward: -1.2600000000000002
# state: action PASS, obs: (31.0, 3, 10, 0, 0, 0), done: False, reward: 0.0
# state: action RUN, obs: (34.0, 2, 7.0, 0, 0, 0), done: False, reward: 0.0
# state: action PUNT, obs: (80.0, 1, 7.0, 1, 0, 0), done: True, reward: -1.3999999999999997
# state: action RUN, obs: (24.0, 2, 6.0, 0, 0, 0), done: False, reward: 0.0
# state: action QB_SNEAK, obs: (34.0, 3, 10, 0, 0, 0), done: False, reward: 0.0
# state: action PASS, obs: (34.0, 2, 10.0, 0, 0, 0), done: False, reward: 0.0
# state: action QB_SNEAK, obs: (44.0, 3, 10, 0, 0, 0), done: False, reward: 0.0
# state: action PUNT, obs: (75.0, 2, 10, 1, 0, 0), done: True, reward: -1.75
# state: action FIELD_GOAL, obs: (10, 2, 10, 1, 0, 0), done: True, reward: -6.3
# state: action QB_SNEAK, obs: (25.0, 2, 5.0, 0, 0, 0), done: False, reward: 0.0
# state: action QB_SNEAK, obs: (28.0, 1, 2.0, 0, 0, 0), done: False, reward: 0.0
# state: action FIELD_GOAL, obs: (18.0, 0, 2.0, 1, 0, 0), done: True, reward: -5.74
# state: action RUN, obs: (27.0, 2, 3.0, 0, 0, 0), done: False, reward: 0.0
# state: action QB_SNEAK, obs: (29.0, 1, 1.0, 0, 0, 0), done: False, reward: 0.0
# state: action PASS, obs: (37.0, 3, 10, 0, 0, 0), done: False, reward: 0.0
# state: action RUN, obs: (45.0, 2, 2.0, 0, 0, 0), done: False, reward: 0.0
# state: action FIELD_GOAL, obs: (35.0, 1, 2.0, 1, 0, 0), done: True, reward: -4.55
# state: action RUN, obs: (26.0, 2, 4.0, 0, 0, 0), done: False, reward: 0.0
# state: action FIELD_GOAL, obs: (16.0, 1, 4.0, 1, 0, 0), done: True, reward: -5.88
# state: action FIELD_GOAL, obs: (10, 2, 10, 1, 0, 0), done: True, reward: -6.3
# state: action PUNT, obs: (60.0, 2, 10, 1, 0, 0), done: True, reward: -2.8000000000000003
# state: action FIELD_GOAL, obs: (10, 2, 10, 1, 0, 0), done: True, reward: -6.3
# state: action PASS, obs: (25.0, 2, 5.0, 0, 0, 0), done: False, reward: 0.0
# state: action RUN, obs: (27.0, 1, 3.0, 0, 0, 0), done: False, reward: 0.0
# state: action FIELD_GOAL, obs: (17.0, 0, 3.0, 1, 0, 0), done: True, reward: -5.81
# state: action PASS, obs: (20.0, 2, 10.0, 0, 0, 0), done: False, reward: 0.0
# state: action PASS, obs: (33.0, 3, 10, 0, 0, 0), done: False, reward: 0.0
# state: action QB_SNEAK, obs: (38.0, 2, 5.0, 0, 0, 0), done: False, reward: 0.0
# state: action RUN, obs: (41.0, 1, 2.0, 0, 0, 0), done: False, reward: 0.0
# state: action FIELD_GOAL, obs: (31.0, 0, 2.0, 1, 0, 0), done: True, reward: -4.83
# state: action FIELD_GOAL, obs: (10, 2, 10, 1, 0, 0), done: True, reward: -6.3
# state: action RUN, obs: (24.0, 2, 6.0, 0, 0, 0), done: False, reward: 0.0
# state: action FIELD_GOAL, obs: (14.0, 1, 6.0, 1, 0, 0), done: True, reward: -6.02
# state: action PASS, obs: (20.0, 2, 10.0, 0, 0, 0), done: False, reward: 0.0
# state: action PASS, obs: (3.0, 1, 27.0, 0, 0, 0), done: False, reward: 0.0
# state: action FIELD_GOAL, obs: (-7.0, 0, 27.0, 1, 0, 0), done: True, reward: -7.49
# state: action PUNT, obs: (74.0, 2, 10, 1, 0, 0), done: True, reward: -1.82
# state: action FIELD_GOAL, obs: (10, 2, 10, 1, 0, 0), done: True, reward: -6.3
# state: action QB_SNEAK, obs: (24.0, 2, 6.0, 0, 0, 0), done: False, reward: 0.0
# state: action RUN, obs: (28.0, 1, 2.0, 0, 0, 0), done: False, reward: 0.0
# state: action PASS, obs: (27.0, 0, 3.0, 0, 0, 0), done: True, reward: -5.109999999999999
# state: action QB_SNEAK, obs: (24.0, 2, 6.0, 0, 0, 0), done: False, reward: 0.0
# state: action QB_SNEAK, obs: (26.0, 1, 4.0, 0, 0, 0), done: False, reward: 0.0
# state: action RUN, obs: (36.0, 3, 10, 0, 0, 0), done: False, reward: 0.0
# state: action RUN, obs: (35.0, 2, 11.0, 0, 0, 0), done: False, reward: 0.0
# state: action QB_SNEAK, obs: (39.0, 1, 7.0, 0, 0, 0), done: False, reward: 0.0
# state: action RUN, obs: (43.0, 0, 3.0, 0, 0, 0), done: True, reward: -3.99
# state: action RUN, obs: (24.0, 2, 6.0, 0, 0, 0), done: False, reward: 0.0
# state: action FIELD_GOAL, obs: (14.0, 1, 6.0, 1, 0, 0), done: True, reward: -6.02
# state: action PUNT, obs: (68.0, 2, 10, 1, 0, 0), done: True, reward: -2.2399999999999998
# state: action QB_SNEAK, obs: (24.0, 2, 6.0, 0, 0, 0), done: False, reward: 0.0
# state: action QB_SNEAK, obs: (33.0, 3, 10, 0, 0, 0), done: False, reward: 0.0
# state: action RUN, obs: (33.0, 2, 10.0, 0, 0, 0), done: False, reward: 0.0
# state: action PASS, obs: (33.0, 1, 10.0, 0, 0, 0), done: False, reward: 0.0
# state: action PUNT, obs: (80.0, 0, 10.0, 1, 0, 0), done: True, reward: -1.3999999999999997
# state: action PUNT, obs: (73.0, 2, 10, 1, 0, 0), done: True, reward: -1.8900000000000001
# state: action QB_SNEAK, obs: (27.0, 2, 3.0, 0, 0, 0), done: False, reward: 0.0
# state: action FIELD_GOAL, obs: (17.0, 1, 3.0, 1, 0, 0), done: True, reward: -5.81
# state: action FIELD_GOAL, obs: (10, 2, 10, 1, 0, 0), done: True, reward: -6.3
# state: action QB_SNEAK, obs: (26.0, 2, 4.0, 0, 0, 0), done: False, reward: 0.0
# state: action PASS, obs: (29.0, 1, 1.0, 0, 0, 0), done: False, reward: 0.0
# state: action RUN, obs: (35.0, 3, 10, 0, 0, 0), done: False, reward: 0.0
# state: action PASS, obs: (56.0, 3, 10, 0, 0, 0), done: False, reward: 0.0
# state: action RUN, obs: (53.0, 2, 13.0, 0, 0, 0), done: False, reward: 0.0
# state: action FIELD_GOAL, obs: (53.0, 1, 13.0, 1, 0, 0), done: True, reward: -3.29
# state: action PASS, obs: (37.0, 3, 10, 0, 0, 0), done: False, reward: 0.0
# state: action PASS, obs: (47.0, 3, 10, 0, 0, 0), done: False, reward: 0.0
# state: action PASS, obs: (57.0, 3, 10, 0, 0, 0), done: False, reward: 0.0
# state: action FIELD_GOAL, obs: (57.0, 2, 10, 0, 0, 1), done: True, reward: 3.0
# state: action PASS, obs: (20.0, 2, 10.0, 0, 0, 0), done: False, reward: 0.0
# state: action PASS, obs: (100, 1, 10.0, 0, 1, 0), done: True, reward: 7.0
# state: action QB_SNEAK, obs: (29.0, 2, 1.0, 0, 0, 0), done: False, reward: 0.0
# state: action RUN, obs: (29.0, 1, 1.0, 0, 0, 0), done: False, reward: 0.0
# state: action PUNT, obs: (72.0, 0, 1.0, 1, 0, 0), done: True, reward: -1.9600000000000002
# state: action PASS, obs: (24.0, 2, 6.0, 0, 0, 0), done: False, reward: 0.0
# state: action PASS, obs: (35.0, 3, 10, 0, 0, 0), done: False, reward: 0.0
# state: action FIELD_GOAL, obs: (25.0, 2, 10, 1, 0, 0), done: True, reward: -5.25
# state: action FIELD_GOAL, obs: (10, 2, 10, 1, 0, 0), done: True, reward: -6.3
# state: action FIELD_GOAL, obs: (10, 2, 10, 1, 0, 0), done: True, reward: -6.3
# state: action PASS, obs: (51.0, 3, 10, 0, 0, 0), done: False, reward: 0.0
# state: action RUN, obs: (55.0, 2, 6.0, 0, 0, 0), done: False, reward: 0.0
# state: action RUN, obs: (56.0, 1, 5.0, 0, 0, 0), done: False, reward: 0.0
# state: action RUN, obs: (59.0, 0, 2.0, 0, 0, 0), done: True, reward: -2.87
# state: action FIELD_GOAL, obs: (10, 2, 10, 1, 0, 0), done: True, reward: -6.3
# state: action PASS, obs: (25.0, 2, 5.0, 0, 0, 0), done: False, reward: 0.0
# state: action RUN, obs: (33.0, 3, 10, 0, 0, 0), done: False, reward: 0.0
# state: action FIELD_GOAL, obs: (23.0, 2, 10, 1, 0, 0), done: True, reward: -5.390000000000001
# state: action PUNT, obs: (74.0, 2, 10, 1, 0, 0), done: True, reward: -1.82
# state: action FIELD_GOAL, obs: (10, 2, 10, 1, 0, 0), done: True, reward: -6.3
# state: action PASS, obs: (39.0, 3, 10, 0, 0, 0), done: False, reward: 0.0
# state: action QB_SNEAK, obs: (40.0, 2, 9.0, 0, 0, 0), done: False, reward: 0.0
# state: action RUN, obs: (41.0, 1, 8.0, 0, 0, 0), done: False, reward: 0.0
# state: action QB_SNEAK, obs: (48.0, 0, 1.0, 0, 0, 0), done: True, reward: -3.64
# state: action PUNT, obs: (75.0, 2, 10, 1, 0, 0), done: True, reward: -1.75
# state: action QB_SNEAK, obs: (25.0, 2, 5.0, 0, 0, 0), done: False, reward: 0.0
# state: action PASS, obs: (34.0, 3, 10, 0, 0, 0), done: False, reward: 0.0
# state: action PUNT, obs: (85.0, 2, 10, 1, 0, 0), done: True, reward: -1.0500000000000003
# state: action PUNT, obs: (81.0, 2, 10, 1, 0, 0), done: True, reward: -1.3299999999999996
# state: action FIELD_GOAL, obs: (10, 2, 10, 1, 0, 0), done: True, reward: -6.3
# state: action PASS, obs: (25.0, 2, 5.0, 0, 0, 0), done: False, reward: 0.0
# state: action FIELD_GOAL, obs: (15.0, 1, 5.0, 1, 0, 0), done: True, reward: -5.95
# state: action QB_SNEAK, obs: (21.0, 2, 9.0, 0, 0, 0), done: False, reward: 0.0
# state: action PASS, obs: (21.0, 1, 9.0, 0, 0, 0), done: False, reward: 0.0
# state: action PASS, obs: (21.0, 0, 9.0, 0, 0, 0), done: True, reward: -5.53
# state: action PASS, obs: (20.0, 2, 10.0, 0, 0, 0), done: False, reward: 0.0
# state: action FIELD_GOAL, obs: (10.0, 1, 10.0, 1, 0, 0), done: True, reward: -6.3
# state: action PASS, obs: (52.0, 2, 10, 1, 0, 0), done: True, reward: -3.36
# state: action FIELD_GOAL, obs: (10, 2, 10, 1, 0, 0), done: True, reward: -6.3
# state: action RUN, obs: (23.0, 2, 7.0, 0, 0, 0), done: False, reward: 0.0
# state: action QB_SNEAK, obs: (31.0, 3, 10, 0, 0, 0), done: False, reward: 0.0
# state: action PUNT, obs: (89.0, 2, 10, 1, 0, 0), done: True, reward: -0.7699999999999999
# state: action QB_SNEAK, obs: (24.0, 2, 6.0, 0, 0, 0), done: False, reward: 0.0
# state: action FIELD_GOAL, obs: (14.0, 1, 6.0, 1, 0, 0), done: True, reward: -6.02
# state: action QB_SNEAK, obs: (21.0, 2, 9.0, 0, 0, 0), done: False, reward: 0.0
# state: action PASS, obs: (21.0, 1, 9.0, 0, 0, 0), done: False, reward: 0.0
# state: action PASS, obs: (21.0, 0, 9.0, 0, 0, 0), done: True, reward: -5.53
# state: action PUNT, obs: (66.0, 2, 10, 1, 0, 0), done: True, reward: -2.38
# state: action RUN, obs: (21.0, 2, 9.0, 0, 0, 0), done: False, reward: 0.0
# state: action QB_SNEAK, obs: (25.0, 1, 5.0, 0, 0, 0), done: False, reward: 0.0
# state: action FIELD_GOAL, obs: (15.0, 0, 5.0, 1, 0, 0), done: True, reward: -5.95
# state: action QB_SNEAK, obs: (32.0, 3, 10, 0, 0, 0), done: False, reward: 0.0
# state: action RUN, obs: (30.0, 2, 12.0, 0, 0, 0), done: False, reward: 0.0
# state: action PUNT, obs: (65.0, 1, 12.0, 1, 0, 0), done: True, reward: -2.4499999999999997
# state: action FIELD_GOAL, obs: (10, 2, 10, 1, 0, 0), done: True, reward: -6.3
# state: action FIELD_GOAL, obs: (10, 2, 10, 1, 0, 0), done: True, reward: -6.3
# state: action FIELD_GOAL, obs: (10, 2, 10, 1, 0, 0), done: True, reward: -6.3
# state: action FIELD_GOAL, obs: (10, 2, 10, 1, 0, 0), done: True, reward: -6.3
# state: action PASS, obs: (20.0, 2, 10.0, 0, 0, 0), done: False, reward: 0.0
# state: action RUN, obs: (20.0, 1, 10.0, 0, 0, 0), done: False, reward: 0.0
# state: action RUN, obs: (23.0, 0, 7.0, 0, 0, 0), done: True, reward: -5.390000000000001
# state: action RUN, obs: (23.0, 2, 7.0, 0, 0, 0), done: False, reward: 0.0
# state: action PASS, obs: (39.0, 3, 10, 0, 0, 0), done: False, reward: 0.0
# state: action PUNT, obs: (90.0, 2, 10, 1, 0, 0), done: True, reward: -0.6999999999999998
# state: action FIELD_GOAL, obs: (10, 2, 10, 1, 0, 0), done: True, reward: -6.3
# state: action PASS, obs: (20.0, 2, 10.0, 0, 0, 0), done: False, reward: 0.0
# state: action FIELD_GOAL, obs: (10.0, 1, 10.0, 1, 0, 0), done: True, reward: -6.3
# state: action QB_SNEAK, obs: (35.0, 3, 10, 0, 0, 0), done: False, reward: 0.0
# state: action QB_SNEAK, obs: (100, 2, 10, 0, 1, 0), done: True, reward: 7.0
# state: action PASS, obs: (27.0, 2, 3.0, 0, 0, 0), done: False, reward: 0.0
# state: action QB_SNEAK, obs: (36.0, 3, 10, 0, 0, 0), done: False, reward: 0.0
# state: action RUN, obs: (41.0, 2, 5.0, 0, 0, 0), done: False, reward: 0.0
# state: action FIELD_GOAL, obs: (31.0, 1, 5.0, 1, 0, 0), done: True, reward: -4.83
# state: action FIELD_GOAL, obs: (10, 2, 10, 1, 0, 0), done: True, reward: -6.3
# state: action QB_SNEAK, obs: (23.0, 2, 7.0, 0, 0, 0), done: False, reward: 0.0
# state: action PASS, obs: (23.0, 1, 7.0, 0, 0, 0), done: False, reward: 0.0
# state: action PASS, obs: (23.0, 0, 7.0, 0, 0, 0), done: True, reward: -5.390000000000001
# state: action FIELD_GOAL, obs: (10, 2, 10, 1, 0, 0), done: True, reward: -6.3
# state: action QB_SNEAK, obs: (32.0, 3, 10, 0, 0, 0), done: False, reward: 0.0
# state: action PASS, obs: (43.0, 3, 10, 0, 0, 0), done: False, reward: 0.0
# state: action PUNT, obs: (85.0, 2, 10, 1, 0, 0), done: True, reward: -1.0500000000000003
# state: action PASS, obs: (20.0, 2, 10.0, 0, 0, 0), done: False, reward: 0.0
# state: action QB_SNEAK, obs: (22.0, 1, 8.0, 0, 0, 0), done: False, reward: 0.0
# state: action PUNT, obs: (68.0, 0, 8.0, 1, 0, 0), done: True, reward: -2.2399999999999998
# state: action PUNT, obs: (73.0, 2, 10, 1, 0, 0), done: True, reward: -1.8900000000000001
# state: action RUN, obs: (26.0, 2, 4.0, 0, 0, 0), done: False, reward: 0.0
# state: action RUN, obs: (24.0, 1, 6.0, 0, 0, 0), done: False, reward: 0.0
# state: action QB_SNEAK, obs: (34.0, 3, 10, 0, 0, 0), done: False, reward: 0.0
# state: action RUN, obs: (36.0, 2, 8.0, 0, 0, 0), done: False, reward: 0.0
# state: action FIELD_GOAL, obs: (26.0, 1, 8.0, 1, 0, 0), done: True, reward: -5.18
# state: action RUN, obs: (20.0, 2, 10.0, 0, 0, 0), done: False, reward: 0.0
# state: action PASS, obs: (27.0, 1, 3.0, 0, 0, 0), done: False, reward: 0.0
# state: action QB_SNEAK, obs: (32.0, 3, 10, 0, 0, 0), done: False, reward: 0.0
# state: action QB_SNEAK, obs: (39.0, 2, 3.0, 0, 0, 0), done: False, reward: 0.0
# state: action RUN, obs: (48.0, 3, 10, 0, 0, 0), done: False, reward: 0.0
# state: action QB_SNEAK, obs: (51.0, 2, 7.0, 0, 0, 0), done: False, reward: 0.0
# state: action QB_SNEAK, obs: (54.0, 1, 4.0, 0, 0, 0), done: False, reward: 0.0
# state: action PASS, obs: (54.0, 0, 4.0, 0, 0, 0), done: True, reward: -3.2199999999999998
# state: action QB_SNEAK, obs: (23.0, 2, 7.0, 0, 0, 0), done: False, reward: 0.0
# state: action FIELD_GOAL, obs: (13.0, 1, 7.0, 1, 0, 0), done: True, reward: -6.09
# state: action RUN, obs: (21.0, 2, 9.0, 0, 0, 0), done: False, reward: 0.0
# state: action RUN, obs: (29.0, 1, 1.0, 0, 0, 0), done: False, reward: 0.0
# state: action FIELD_GOAL, obs: (19.0, 0, 1.0, 1, 0, 0), done: True, reward: -5.67
# state: action PUNT, obs: (60.0, 2, 10, 1, 0, 0), done: True, reward: -2.8000000000000003
# state: action FIELD_GOAL, obs: (10, 2, 10, 1, 0, 0), done: True, reward: -6.3
# state: action PASS, obs: (28.0, 2, 2.0, 0, 0, 0), done: False, reward: 0.0
# state: action PASS, obs: (34.0, 3, 10, 0, 0, 0), done: False, reward: 0.0
# state: action QB_SNEAK, obs: (39.0, 2, 5.0, 0, 0, 0), done: False, reward: 0.0
# state: action FIELD_GOAL, obs: (39.0, 1, 5.0, 1, 0, 0), done: True, reward: -4.27
# state: action RUN, obs: (24.0, 2, 6.0, 0, 0, 0), done: False, reward: 0.0
# state: action RUN, obs: (29.0, 1, 1.0, 0, 0, 0), done: False, reward: 0.0
# state: action FIELD_GOAL, obs: (19.0, 0, 1.0, 1, 0, 0), done: True, reward: -5.67
# state: action FIELD_GOAL, obs: (10, 2, 10, 1, 0, 0), done: True, reward: -6.3
# state: action PASS, obs: (20.0, 2, 10.0, 0, 0, 0), done: False, reward: 0.0
# state: action PUNT, obs: (68.0, 1, 10.0, 1, 0, 0), done: True, reward: -2.2399999999999998
# state: action RUN, obs: (28.0, 2, 2.0, 0, 0, 0), done: False, reward: 0.0
# state: action QB_SNEAK, obs: (33.0, 3, 10, 0, 0, 0), done: False, reward: 0.0
# state: action PASS, obs: (33.0, 2, 10.0, 0, 0, 0), done: False, reward: 0.0
# state: action QB_SNEAK, obs: (41.0, 1, 2.0, 0, 0, 0), done: False, reward: 0.0
# state: action RUN, obs: (43.0, 3, 10, 0, 0, 0), done: False, reward: 0.0
# state: action FIELD_GOAL, obs: (33.0, 2, 10, 1, 0, 0), done: True, reward: -4.6899999999999995
# state: action RUN, obs: (21.0, 2, 9.0, 0, 0, 0), done: False, reward: 0.0
# state: action RUN, obs: (23.0, 1, 7.0, 0, 0, 0), done: False, reward: 0.0
# state: action QB_SNEAK, obs: (31.0, 3, 10, 0, 0, 0), done: False, reward: 0.0
# state: action PASS, obs: (43.0, 3, 10, 0, 0, 0), done: False, reward: 0.0
# state: action RUN, obs: (45.0, 2, 8.0, 0, 0, 0), done: False, reward: 0.0
# state: action FIELD_GOAL, obs: (35.0, 1, 8.0, 1, 0, 0), done: True, reward: -4.55
# Done with sample: 1   --- 167.58769059181213 seconds ---
# 0.9116444444444174
# state: action PASS, obs: (20.0, 2, 10.0, 0, 0, 0), done: False, reward: 0.0
# state: action PASS, obs: (20.0, 1, 10.0, 0, 0, 0), done: False, reward: 0.0
# state: action QB_SNEAK, obs: (28.0, 0, 2.0, 0, 0, 0), done: True, reward: -5.04
# state: action QB_SNEAK, obs: (21.0, 2, 9.0, 0, 0, 0), done: False, reward: 0.0
# state: action PASS, obs: (21.0, 1, 9.0, 0, 0, 0), done: False, reward: 0.0
# state: action FIELD_GOAL, obs: (11.0, 0, 9.0, 1, 0, 0), done: True, reward: -6.23
# state: action RUN, obs: (23.0, 2, 7.0, 0, 0, 0), done: False, reward: 0.0
# state: action RUN, obs: (25.0, 1, 5.0, 0, 0, 0), done: False, reward: 0.0
# state: action RUN, obs: (30.0, 3, 10, 0, 0, 0), done: False, reward: 0.0
# state: action FIELD_GOAL, obs: (20.0, 2, 10, 1, 0, 0), done: True, reward: -5.6000000000000005
# state: action FIELD_GOAL, obs: (10, 2, 10, 1, 0, 0), done: True, reward: -6.3
# state: action PUNT, obs: (70.0, 2, 10, 1, 0, 0), done: True, reward: -2.1000000000000005
# state: action FIELD_GOAL, obs: (10, 2, 10, 1, 0, 0), done: True, reward: -6.3
# state: action PUNT, obs: (80.0, 2, 10, 1, 0, 0), done: True, reward: -1.3999999999999997
# state: action FIELD_GOAL, obs: (10, 2, 10, 1, 0, 0), done: True, reward: -6.3
# state: action RUN, obs: (14.0, 2, 16.0, 0, 0, 0), done: False, reward: 0.0
# state: action RUN, obs: (19.0, 1, 11.0, 0, 0, 0), done: False, reward: 0.0
# state: action PUNT, obs: (76.0, 0, 11.0, 1, 0, 0), done: True, reward: -1.68
# state: action RUN, obs: (19.0, 2, 11.0, 0, 0, 0), done: False, reward: 0.0
# state: action RUN, obs: (28.0, 1, 2.0, 0, 0, 0), done: False, reward: 0.0
# state: action QB_SNEAK, obs: (40.0, 3, 10, 0, 0, 0), done: False, reward: 0.0
# state: action RUN, obs: (56.0, 3, 10, 0, 0, 0), done: False, reward: 0.0
# state: action RUN, obs: (62.0, 2, 4.0, 0, 0, 0), done: False, reward: 0.0
# state: action PUNT, obs: (87.0, 1, 4.0, 1, 0, 0), done: True, reward: -0.91
# state: action PASS, obs: (24.0, 2, 6.0, 0, 0, 0), done: False, reward: 0.0
# state: action PUNT, obs: (61.0, 1, 6.0, 1, 0, 0), done: True, reward: -2.73
# state: action FIELD_GOAL, obs: (10, 2, 10, 1, 0, 0), done: True, reward: -6.3
# state: action PUNT, obs: (72.0, 2, 10, 1, 0, 0), done: True, reward: -1.9600000000000002
# state: action QB_SNEAK, obs: (24.0, 2, 6.0, 0, 0, 0), done: False, reward: 0.0
# state: action FIELD_GOAL, obs: (14.0, 1, 6.0, 1, 0, 0), done: True, reward: -6.02
# state: action PASS, obs: (25.0, 2, 5.0, 0, 0, 0), done: False, reward: 0.0
# state: action QB_SNEAK, obs: (28.0, 1, 2.0, 0, 0, 0), done: False, reward: 0.0
# state: action RUN, obs: (31.0, 3, 10, 0, 0, 0), done: False, reward: 0.0
# state: action PUNT, obs: (76.0, 2, 10, 1, 0, 0), done: True, reward: -1.68
# state: action QB_SNEAK, obs: (29.0, 2, 1.0, 0, 0, 0), done: False, reward: 0.0
# state: action FIELD_GOAL, obs: (19.0, 1, 1.0, 1, 0, 0), done: True, reward: -5.67
# state: action FIELD_GOAL, obs: (10, 2, 10, 1, 0, 0), done: True, reward: -6.3
# state: action PASS, obs: (20.0, 2, 10.0, 0, 0, 0), done: False, reward: 0.0
# state: action QB_SNEAK, obs: (26.0, 1, 4.0, 0, 0, 0), done: False, reward: 0.0
# state: action PASS, obs: (39.0, 3, 10, 0, 0, 0), done: False, reward: 0.0
# state: action PUNT, obs: (86.0, 2, 10, 1, 0, 0), done: True, reward: -0.9800000000000001
# state: action PASS, obs: (25.0, 2, 5.0, 0, 0, 0), done: False, reward: 0.0
# state: action PASS, obs: (27.0, 1, 3.0, 0, 0, 0), done: False, reward: 0.0
# state: action FIELD_GOAL, obs: (17.0, 0, 3.0, 1, 0, 0), done: True, reward: -5.81
# state: action QB_SNEAK, obs: (29.0, 2, 1.0, 0, 0, 0), done: False, reward: 0.0
# state: action PASS, obs: (29.0, 1, 1.0, 0, 0, 0), done: False, reward: 0.0
# state: action PUNT, obs: (82.0, 0, 1.0, 1, 0, 0), done: True, reward: -1.2600000000000002
# state: action QB_SNEAK, obs: (43.0, 3, 10, 0, 0, 0), done: False, reward: 0.0
# state: action RUN, obs: (50.0, 2, 3.0, 0, 0, 0), done: False, reward: 0.0
# state: action PUNT, obs: (86.0, 1, 3.0, 1, 0, 0), done: True, reward: -0.9800000000000001
# state: action QB_SNEAK, obs: (23.0, 2, 7.0, 0, 0, 0), done: False, reward: 0.0
# state: action PUNT, obs: (90.0, 1, 7.0, 1, 0, 0), done: True, reward: -0.6999999999999998
# state: action RUN, obs: (24.0, 2, 6.0, 0, 0, 0), done: False, reward: 0.0
# state: action PUNT, obs: (76.0, 1, 6.0, 1, 0, 0), done: True, reward: -1.68
# state: action QB_SNEAK, obs: (22.0, 2, 8.0, 0, 0, 0), done: False, reward: 0.0
# state: action RUN, obs: (24.0, 1, 6.0, 0, 0, 0), done: False, reward: 0.0
# state: action PASS, obs: (31.0, 3, 10, 0, 0, 0), done: False, reward: 0.0
# state: action PASS, obs: (37.0, 2, 4.0, 0, 0, 0), done: False, reward: 0.0
# state: action QB_SNEAK, obs: (43.0, 3, 10, 0, 0, 0), done: False, reward: 0.0
# state: action QB_SNEAK, obs: (47.0, 2, 6.0, 0, 0, 0), done: False, reward: 0.0
# state: action FIELD_GOAL, obs: (37.0, 1, 6.0, 1, 0, 0), done: True, reward: -4.41
# state: action RUN, obs: (10.0, 2, 20.0, 0, 0, 0), done: False, reward: 0.0
# state: action RUN, obs: (14.0, 1, 16.0, 0, 0, 0), done: False, reward: 0.0
# state: action FIELD_GOAL, obs: (4.0, 0, 16.0, 1, 0, 0), done: True, reward: -6.72
# state: action PASS, obs: (63.0, 3, 10, 0, 0, 0), done: False, reward: 0.0
# state: action FIELD_GOAL, obs: (63.0, 2, 10, 1, 0, 0), done: True, reward: -2.59
# state: action QB_SNEAK, obs: (29.0, 2, 1.0, 0, 0, 0), done: False, reward: 0.0
# state: action RUN, obs: (28.0, 1, 2.0, 0, 0, 0), done: False, reward: 0.0
# state: action FIELD_GOAL, obs: (18.0, 0, 2.0, 1, 0, 0), done: True, reward: -5.74
# state: action RUN, obs: (24.0, 2, 6.0, 0, 0, 0), done: False, reward: 0.0
# state: action PASS, obs: (33.0, 3, 10, 0, 0, 0), done: False, reward: 0.0
# state: action RUN, obs: (37.0, 2, 6.0, 0, 0, 0), done: False, reward: 0.0
# state: action PUNT, obs: (87.0, 1, 6.0, 1, 0, 0), done: True, reward: -0.91
# state: action PUNT, obs: (72.0, 2, 10, 1, 0, 0), done: True, reward: -1.9600000000000002
# state: action QB_SNEAK, obs: (29.0, 2, 1.0, 0, 0, 0), done: False, reward: 0.0
# state: action QB_SNEAK, obs: (32.0, 3, 10, 0, 0, 0), done: False, reward: 0.0
# state: action PASS, obs: (35.0, 2, 7.0, 0, 0, 0), done: False, reward: 0.0
# state: action QB_SNEAK, obs: (56.0, 3, 10, 0, 0, 0), done: False, reward: 0.0
# state: action PUNT, obs: (90.0, 2, 10, 1, 0, 0), done: True, reward: -0.6999999999999998
# state: action QB_SNEAK, obs: (42.0, 3, 10, 0, 0, 0), done: False, reward: 0.0
# state: action RUN, obs: (47.0, 2, 5.0, 0, 0, 0), done: False, reward: 0.0
# state: action FIELD_GOAL, obs: (37.0, 1, 5.0, 1, 0, 0), done: True, reward: -4.41
# state: action PASS, obs: (32.0, 3, 10, 0, 0, 0), done: False, reward: 0.0
# state: action RUN, obs: (39.0, 2, 3.0, 0, 0, 0), done: False, reward: 0.0
# state: action PUNT, obs: (84.0, 1, 3.0, 1, 0, 0), done: True, reward: -1.12
# state: action QB_SNEAK, obs: (25.0, 2, 5.0, 0, 0, 0), done: False, reward: 0.0
# state: action PASS, obs: (32.0, 3, 10, 0, 0, 0), done: False, reward: 0.0
# state: action FIELD_GOAL, obs: (22.0, 2, 10, 1, 0, 0), done: True, reward: -5.46
# state: action PASS, obs: (34.0, 3, 10, 0, 0, 0), done: False, reward: 0.0
# state: action RUN, obs: (46.0, 3, 10, 0, 0, 0), done: False, reward: 0.0
# state: action QB_SNEAK, obs: (52.0, 2, 4.0, 0, 0, 0), done: False, reward: 0.0
# state: action RUN, obs: (57.0, 3, 10, 0, 0, 0), done: False, reward: 0.0
# state: action QB_SNEAK, obs: (64.0, 2, 3.0, 0, 0, 0), done: False, reward: 0.0
# state: action FIELD_GOAL, obs: (64.0, 1, 3.0, 0, 0, 1), done: True, reward: 3.0
# state: action RUN, obs: (24.0, 2, 6.0, 0, 0, 0), done: False, reward: 0.0
# state: action RUN, obs: (25.0, 1, 5.0, 0, 0, 0), done: False, reward: 0.0
# state: action FIELD_GOAL, obs: (15.0, 0, 5.0, 1, 0, 0), done: True, reward: -5.95
# state: action PASS, obs: (24.0, 2, 6.0, 0, 0, 0), done: False, reward: 0.0
# state: action FIELD_GOAL, obs: (14.0, 1, 6.0, 1, 0, 0), done: True, reward: -6.02
# state: action PASS, obs: (76.0, 3, 10, 0, 0, 0), done: False, reward: 0.0
# state: action RUN, obs: (78.0, 2, 8.0, 0, 0, 0), done: False, reward: 0.0
# state: action PASS, obs: (100, 1, 8.0, 0, 1, 0), done: True, reward: 7.0
# state: action FIELD_GOAL, obs: (10, 2, 10, 1, 0, 0), done: True, reward: -6.3
# state: action QB_SNEAK, obs: (25.0, 2, 5.0, 0, 0, 0), done: False, reward: 0.0
# state: action QB_SNEAK, obs: (32.0, 3, 10, 0, 0, 0), done: False, reward: 0.0
# state: action PASS, obs: (32.0, 2, 10.0, 0, 0, 0), done: False, reward: 0.0
# state: action PASS, obs: (37.0, 1, 5.0, 0, 0, 0), done: False, reward: 0.0
# state: action PASS, obs: (50.0, 3, 10, 0, 0, 0), done: False, reward: 0.0
# state: action RUN, obs: (57.0, 2, 3.0, 0, 0, 0), done: False, reward: 0.0
# state: action FIELD_GOAL, obs: (57.0, 1, 3.0, 1, 0, 0), done: True, reward: -3.0100000000000002
# state: action PASS, obs: (29.0, 2, 1.0, 0, 0, 0), done: False, reward: 0.0
# state: action FIELD_GOAL, obs: (19.0, 1, 1.0, 1, 0, 0), done: True, reward: -5.67
# ...
# state: action PASS, obs: (37.0, 3, 10, 0, 0, 0), done: False, reward: 0.0
# state: action QB_SNEAK, obs: (43.0, 2, 4.0, 0, 0, 0), done: False, reward: 0.0
# state: action QB_SNEAK, obs: (45.0, 1, 2.0, 0, 0, 0), done: False, reward: 0.0
# state: action QB_SNEAK, obs: (50.0, 3, 10, 0, 0, 0), done: False, reward: 0.0
# state: action QB_SNEAK, obs: (67.0, 3, 10, 0, 0, 0), done: False, reward: 0.0
# state: action QB_SNEAK, obs: (70.0, 2, 7.0, 0, 0, 0), done: False, reward: 0.0
# state: action QB_SNEAK, obs: (81.0, 3, 10, 0, 0, 0), done: False, reward: 0.0
# state: action QB_SNEAK, obs: (86.0, 2, 5.0, 0, 0, 0), done: False, reward: 0.0
# state: action QB_SNEAK, obs: (88.0, 1, 3.0, 0, 0, 0), done: False, reward: 0.0
# state: action QB_SNEAK, obs: (90.0, 0, 1.0, 0, 0, 0), done: True, reward: -0.6999999999999998
# state: action PASS, obs: (20.0, 2, 10.0, 0, 0, 0), done: False, reward: 0.0
# state: action PASS, obs: (29.0, 1, 1.0, 0, 0, 0), done: False, reward: 0.0
# state: action QB_SNEAK, obs: (34.0, 3, 10, 0, 0, 0), done: False, reward: 0.0
# state: action QB_SNEAK, obs: (44.0, 3, 10, 0, 0, 0), done: False, reward: 0.0
# state: action QB_SNEAK, obs: (61.0, 3, 10, 0, 0, 0), done: False, reward: 0.0
# state: action QB_SNEAK, obs: (67.0, 2, 4.0, 0, 0, 0), done: False, reward: 0.0
# state: action QB_SNEAK, obs: (73.0, 3, 10, 0, 0, 0), done: False, reward: 0.0
# state: action QB_SNEAK, obs: (75.0, 2, 8.0, 0, 0, 0), done: False, reward: 0.0
# state: action QB_SNEAK, obs: (80.0, 1, 3.0, 0, 0, 0), done: False, reward: 0.0
# state: action QB_SNEAK, obs: (81.0, 0, 2.0, 0, 0, 0), done: True, reward: -1.3299999999999996
# state: action PASS, obs: (40.0, 3, 10, 0, 0, 0), done: False, reward: 0.0
# state: action QB_SNEAK, obs: (41.0, 2, 9.0, 0, 0, 0), done: False, reward: 0.0
# state: action QB_SNEAK, obs: (45.0, 1, 5.0, 0, 0, 0), done: False, reward: 0.0
# state: action QB_SNEAK, obs: (54.0, 3, 10, 0, 0, 0), done: False, reward: 0.0
# state: action QB_SNEAK, obs: (57.0, 2, 7.0, 0, 0, 0), done: False, reward: 0.0
# state: action QB_SNEAK, obs: (62.0, 1, 2.0, 0, 0, 0), done: False, reward: 0.0
# state: action QB_SNEAK, obs: (68.0, 3, 10, 0, 0, 0), done: False, reward: 0.0
# state: action QB_SNEAK, obs: (69.0, 2, 9.0, 0, 0, 0), done: False, reward: 0.0
# state: action QB_SNEAK, obs: (72.0, 1, 6.0, 0, 0, 0), done: False, reward: 0.0
# state: action QB_SNEAK, obs: (86.0, 3, 10, 0, 0, 0), done: False, reward: 0.0
# state: action QB_SNEAK, obs: (94.0, 2, 2.0, 0, 0, 0), done: False, reward: 0.0
# state: action QB_SNEAK, obs: (96.0, 3, 4.0, 0, 0, 0), done: False, reward: 0.0
# state: action QB_SNEAK, obs: (99.0, 2, 1.0, 0, 0, 0), done: False, reward: 0.0
# state: action QB_SNEAK, obs: (100, 1, 1.0, 0, 1, 0), done: True, reward: 7.0
# state: action PASS, obs: (20.0, 2, 10.0, 0, 0, 0), done: False, reward: 0.0
# state: action PASS, obs: (30.0, 3, 10, 0, 0, 0), done: False, reward: 0.0
# state: action PASS, obs: (30.0, 2, 10.0, 0, 0, 0), done: False, reward: 0.0
# state: action PASS, obs: (30.0, 1, 10.0, 0, 0, 0), done: False, reward: 0.0
# state: action PASS, obs: (47.0, 3, 10, 0, 0, 0), done: False, reward: 0.0
# state: action QB_SNEAK, obs: (64.0, 3, 10, 0, 0, 0), done: False, reward: 0.0
# state: action QB_SNEAK, obs: (79.0, 3, 10, 0, 0, 0), done: False, reward: 0.0
# state: action QB_SNEAK, obs: (84.0, 2, 5.0, 0, 0, 0), done: False, reward: 0.0
# state: action QB_SNEAK, obs: (88.0, 1, 1.0, 0, 0, 0), done: False, reward: 0.0
# state: action QB_SNEAK, obs: (95.0, 3, 5.0, 0, 0, 0), done: False, reward: 0.0
# state: action QB_SNEAK, obs: (100, 2, 5.0, 0, 1, 0), done: True, reward: 7.0
# state: action PASS, obs: (30.0, 3, 10, 0, 0, 0), done: False, reward: 0.0
# state: action PASS, obs: (43.0, 3, 10, 0, 0, 0), done: False, reward: 0.0
# state: action QB_SNEAK, obs: (46.0, 2, 7.0, 0, 0, 0), done: False, reward: 0.0
# state: action QB_SNEAK, obs: (50.0, 1, 3.0, 0, 0, 0), done: False, reward: 0.0
# state: action QB_SNEAK, obs: (53.0, 3, 10, 0, 0, 0), done: False, reward: 0.0
# state: action QB_SNEAK, obs: (54.0, 2, 9.0, 0, 0, 0), done: False, reward: 0.0
# state: action QB_SNEAK, obs: (61.0, 1, 2.0, 0, 0, 0), done: False, reward: 0.0
# state: action QB_SNEAK, obs: (68.0, 3, 10, 0, 0, 0), done: False, reward: 0.0
# state: action QB_SNEAK, obs: (82.0, 3, 10, 0, 0, 0), done: False, reward: 0.0
# state: action QB_SNEAK, obs: (83.0, 2, 9.0, 0, 0, 0), done: False, reward: 0.0
# state: action QB_SNEAK, obs: (91.0, 1, 1.0, 0, 0, 0), done: False, reward: 0.0
# state: action QB_SNEAK, obs: (100, 0, 1.0, 0, 1, 0), done: True, reward: 7.0
# state: action PASS, obs: (30.0, 3, 10, 0, 0, 0), done: False, reward: 0.0
# state: action PASS, obs: (47.0, 3, 10, 0, 0, 0), done: False, reward: 0.0
# state: action QB_SNEAK, obs: (55.0, 2, 2.0, 0, 0, 0), done: False, reward: 0.0
# state: action QB_SNEAK, obs: (57.0, 3, 10, 0, 0, 0), done: False, reward: 0.0
# state: action QB_SNEAK, obs: (62.0, 2, 5.0, 0, 0, 0), done: False, reward: 0.0
# state: action QB_SNEAK, obs: (69.0, 3, 10, 0, 0, 0), done: False, reward: 0.0
# state: action QB_SNEAK, obs: (75.0, 2, 4.0, 0, 0, 0), done: False, reward: 0.0
# state: action QB_SNEAK, obs: (79.0, 3, 10, 0, 0, 0), done: False, reward: 0.0
# state: action QB_SNEAK, obs: (96.0, 3, 4.0, 0, 0, 0), done: False, reward: 0.0
# state: action QB_SNEAK, obs: (100, 2, 4.0, 0, 1, 0), done: True, reward: 7.0
# state: action PASS, obs: (20.0, 2, 10.0, 0, 0, 0), done: False, reward: 0.0
# state: action PASS, obs: (20.0, 1, 10.0, 0, 0, 0), done: False, reward: 0.0
# state: action PASS, obs: (20.0, 0, 10.0, 0, 0, 0), done: True, reward: -5.6000000000000005
# state: action PASS, obs: (53.0, 3, 10, 0, 0, 0), done: False, reward: 0.0
# state: action QB_SNEAK, obs: (56.0, 2, 7.0, 0, 0, 0), done: False, reward: 0.0
# state: action QB_SNEAK, obs: (91.0, 3, 9.0, 0, 0, 0), done: False, reward: 0.0
# state: action QB_SNEAK, obs: (100, 2, 9.0, 0, 1, 0), done: True, reward: 7.0
# state: action PASS, obs: (23.0, 2, 7.0, 0, 0, 0), done: False, reward: 0.0
# state: action PASS, obs: (23.0, 1, 7.0, 0, 0, 0), done: False, reward: 0.0
# state: action PASS, obs: (36.0, 3, 10, 0, 0, 0), done: False, reward: 0.0
# state: action QB_SNEAK, obs: (38.0, 2, 8.0, 0, 0, 0), done: False, reward: 0.0
# state: action QB_SNEAK, obs: (52.0, 3, 10, 0, 0, 0), done: False, reward: 0.0
# state: action QB_SNEAK, obs: (61.0, 2, 1.0, 0, 0, 0), done: False, reward: 0.0
# state: action QB_SNEAK, obs: (63.0, 3, 10, 0, 0, 0), done: False, reward: 0.0
# state: action QB_SNEAK, obs: (75.0, 3, 10, 0, 0, 0), done: False, reward: 0.0
# state: action QB_SNEAK, obs: (87.0, 3, 10, 0, 0, 0), done: False, reward: 0.0
# state: action QB_SNEAK, obs: (93.0, 2, 4.0, 0, 0, 0), done: False, reward: 0.0
# state: action QB_SNEAK, obs: (96.0, 1, 1.0, 0, 0, 0), done: False, reward: 0.0
# state: action QB_SNEAK, obs: (100, 0, 1.0, 0, 1, 0), done: True, reward: 7.0
# state: action QB_SNEAK, obs: (38.0, 3, 10, 0, 0, 0), done: False, reward: 0.0
# state: action QB_SNEAK, obs: (47.0, 2, 1.0, 0, 0, 0), done: False, reward: 0.0
# state: action QB_SNEAK, obs: (61.0, 3, 10, 0, 0, 0), done: False, reward: 0.0
# state: action QB_SNEAK, obs: (68.0, 2, 3.0, 0, 0, 0), done: False, reward: 0.0
# state: action QB_SNEAK, obs: (74.0, 3, 10, 0, 0, 0), done: False, reward: 0.0
# state: action QB_SNEAK, obs: (88.0, 3, 10, 0, 0, 0), done: False, reward: 0.0
# state: action QB_SNEAK, obs: (89.0, 2, 9.0, 0, 0, 0), done: False, reward: 0.0
# state: action QB_SNEAK, obs: (90.0, 1, 8.0, 0, 0, 0), done: False, reward: 0.0
# state: action QB_SNEAK, obs: (91.0, 0, 7.0, 0, 0, 0), done: True, reward: -0.6299999999999998
# Done with sample: 21   --- 2478.710980653763 seconds ---
# -0.2000000000001491
# state: action QB_SNEAK, obs: (32.0, 3, 10, 0, 0, 0), done: False, reward: 0.0
# state: action QB_SNEAK, obs: (45.0, 3, 10, 0, 0, 0), done: False, reward: 0.0
# state: action QB_SNEAK, obs: (52.0, 2, 3.0, 0, 0, 0), done: False, reward: 0.0
# state: action QB_SNEAK, obs: (58.0, 3, 10, 0, 0, 0), done: False, reward: 0.0
# state: action QB_SNEAK, obs: (72.0, 3, 10, 0, 0, 0), done: False, reward: 0.0
# state: action QB_SNEAK, obs: (86.0, 3, 10, 0, 0, 0), done: False, reward: 0.0
# state: action QB_SNEAK, obs: (100, 2, 10, 0, 1, 0), done: True, reward: 7.0
# state: action QB_SNEAK, obs: (21.0, 2, 9.0, 0, 0, 0), done: False, reward: 0.0
# state: action PASS, obs: (13.0, 1, 9.0, 1, 0, 0), done: True, reward: -6.09
# state: action QB_SNEAK, obs: (22.0, 2, 8.0, 0, 0, 0), done: False, reward: 0.0
# state: action QB_SNEAK, obs: (29.0, 1, 1.0, 0, 0, 0), done: False, reward: 0.0
# state: action QB_SNEAK, obs: (33.0, 3, 10, 0, 0, 0), done: False, reward: 0.0
# state: action QB_SNEAK, obs: (41.0, 2, 2.0, 0, 0, 0), done: False, reward: 0.0
# state: action QB_SNEAK, obs: (43.0, 3, 10, 0, 0, 0), done: False, reward: 0.0
# state: action QB_SNEAK, obs: (48.0, 2, 5.0, 0, 0, 0), done: False, reward: 0.0
# state: action QB_SNEAK, obs: (52.0, 1, 1.0, 0, 0, 0), done: False, reward: 0.0
# state: action QB_SNEAK, obs: (55.0, 3, 10, 0, 0, 0), done: False, reward: 0.0
# state: action QB_SNEAK, obs: (58.0, 2, 7.0, 0, 0, 0), done: False, reward: 0.0
# state: action QB_SNEAK, obs: (71.0, 3, 10, 0, 0, 0), done: False, reward: 0.0
# state: action QB_SNEAK, obs: (82.0, 3, 10, 0, 0, 0), done: False, reward: 0.0
# state: action QB_SNEAK, obs: (89.0, 2, 3.0, 0, 0, 0), done: False, reward: 0.0
# state: action QB_SNEAK, obs: (95.0, 3, 5.0, 0, 0, 0), done: False, reward: 0.0
# state: action QB_SNEAK, obs: (98.0, 2, 2.0, 0, 0, 0), done: False, reward: 0.0
# state: action QB_SNEAK, obs: (99.0, 1, 1.0, 0, 0, 0), done: False, reward: 0.0
# state: action QB_SNEAK, obs: (100, 0, 1.0, 0, 1, 0), done: True, reward: 7.0
# state: action QB_SNEAK, obs: (21.0, 2, 9.0, 0, 0, 0), done: False, reward: 0.0
# state: action QB_SNEAK, obs: (48.0, 3, 10, 0, 0, 0), done: False, reward: 0.0
# state: action QB_SNEAK, obs: (52.0, 2, 6.0, 0, 0, 0), done: False, reward: 0.0
# state: action QB_SNEAK, obs: (59.0, 3, 10, 0, 0, 0), done: False, reward: 0.0
# state: action QB_SNEAK, obs: (64.0, 2, 5.0, 0, 0, 0), done: False, reward: 0.0
# state: action QB_SNEAK, obs: (64.0, 1, 5.0, 0, 0, 0), done: False, reward: 0.0
# state: action QB_SNEAK, obs: (73.0, 3, 10, 0, 0, 0), done: False, reward: 0.0
# state: action QB_SNEAK, obs: (84.0, 3, 10, 0, 0, 0), done: False, reward: 0.0
# state: action QB_SNEAK, obs: (90.0, 2, 4.0, 0, 0, 0), done: False, reward: 0.0
# state: action QB_SNEAK, obs: (93.0, 1, 1.0, 0, 0, 0), done: False, reward: 0.0
# state: action QB_SNEAK, obs: (96.0, 3, 4.0, 0, 0, 0), done: False, reward: 0.0
# state: action QB_SNEAK, obs: (99.0, 2, 1.0, 0, 0, 0), done: False, reward: 0.0
# state: action QB_SNEAK, obs: (100, 1, 1.0, 0, 1, 0), done: True, reward: 7.0
# state: action QB_SNEAK, obs: (28.0, 2, 2.0, 0, 0, 0), done: False, reward: 0.0
# state: action QB_SNEAK, obs: (33.0, 3, 10, 0, 0, 0), done: False, reward: 0.0
# state: action QB_SNEAK, obs: (38.0, 2, 5.0, 0, 0, 0), done: False, reward: 0.0
# state: action QB_SNEAK, obs: (53.0, 3, 10, 0, 0, 0), done: False, reward: 0.0
# state: action QB_SNEAK, obs: (54.0, 2, 9.0, 0, 0, 0), done: False, reward: 0.0
# state: action QB_SNEAK, obs: (63.0, 3, 10, 0, 0, 0), done: False, reward: 0.0
# state: action QB_SNEAK, obs: (65.0, 2, 8.0, 0, 0, 0), done: False, reward: 0.0
# state: action QB_SNEAK, obs: (74.0, 3, 10, 0, 0, 0), done: False, reward: 0.0
# state: action QB_SNEAK, obs: (81.0, 2, 3.0, 0, 0, 0), done: False, reward: 0.0
# state: action QB_SNEAK, obs: (81.0, 1, 3.0, 0, 0, 0), done: False, reward: 0.0
# state: action QB_SNEAK, obs: (82.0, 0, 2.0, 0, 0, 0), done: True, reward: -1.2600000000000002
# state: action QB_SNEAK, obs: (30.0, 3, 10, 0, 0, 0), done: False, reward: 0.0
# state: action QB_SNEAK, obs: (35.0, 2, 5.0, 0, 0, 0), done: False, reward: 0.0
# state: action QB_SNEAK, obs: (44.0, 3, 10, 0, 0, 0), done: False, reward: 0.0
# state: action QB_SNEAK, obs: (45.0, 2, 9.0, 0, 0, 0), done: False, reward: 0.0
# state: action QB_SNEAK, obs: (55.0, 3, 10, 0, 0, 0), done: False, reward: 0.0
# state: action QB_SNEAK, obs: (55.0, 2, 10.0, 0, 0, 0), done: False, reward: 0.0
# state: action QB_SNEAK, obs: (68.0, 3, 10, 0, 0, 0), done: False, reward: 0.0
# state: action QB_SNEAK, obs: (82.0, 3, 10, 0, 0, 0), done: False, reward: 0.0
# state: action QB_SNEAK, obs: (93.0, 3, 7.0, 0, 0, 0), done: False, reward: 0.0
# state: action QB_SNEAK, obs: (100, 2, 7.0, 0, 1, 0), done: True, reward: 7.0
# state: action PASS, obs: (19.0, 2, 11.0, 0, 0, 0), done: False, reward: 0.0
# state: action PASS, obs: (43.0, 3, 10, 0, 0, 0), done: False, reward: 0.0
# state: action QB_SNEAK, obs: (60.0, 3, 10, 0, 0, 0), done: False, reward: 0.0
# state: action QB_SNEAK, obs: (74.0, 3, 10, 0, 0, 0), done: False, reward: 0.0
# state: action QB_SNEAK, obs: (77.0, 2, 7.0, 0, 0, 0), done: False, reward: 0.0
# state: action QB_SNEAK, obs: (92.0, 3, 8.0, 0, 0, 0), done: False, reward: 0.0
# state: action QB_SNEAK, obs: (100, 2, 8.0, 0, 1, 0), done: True, reward: 7.0
# state: action PASS, obs: (24.0, 2, 6.0, 0, 0, 0), done: False, reward: 0.0
# state: action PASS, obs: (24.0, 1, 6.0, 0, 0, 0), done: False, reward: 0.0
# state: action PASS, obs: (34.0, 3, 10, 0, 0, 0), done: False, reward: 0.0
# state: action QB_SNEAK, obs: (40.0, 2, 4.0, 0, 0, 0), done: False, reward: 0.0
# state: action QB_SNEAK, obs: (47.0, 3, 10, 0, 0, 0), done: False, reward: 0.0
# state: action QB_SNEAK, obs: (48.0, 2, 10, 1, 0, 0), done: True, reward: -3.64
# state: action PASS, obs: (20.0, 2, 10.0, 0, 0, 0), done: False, reward: 0.0
# state: action PASS, obs: (24.0, 1, 6.0, 0, 0, 0), done: False, reward: 0.0
# state: action PASS, obs: (31.0, 3, 10, 0, 0, 0), done: False, reward: 0.0
# state: action QB_SNEAK, obs: (36.0, 2, 5.0, 0, 0, 0), done: False, reward: 0.0
# state: action QB_SNEAK, obs: (42.0, 3, 10, 0, 0, 0), done: False, reward: 0.0
# state: action QB_SNEAK, obs: (46.0, 2, 6.0, 0, 0, 0), done: False, reward: 0.0
# state: action QB_SNEAK, obs: (52.0, 3, 10, 0, 0, 0), done: False, reward: 0.0
# state: action QB_SNEAK, obs: (59.0, 2, 3.0, 0, 0, 0), done: False, reward: 0.0
# state: action QB_SNEAK, obs: (60.0, 1, 2.0, 0, 0, 0), done: False, reward: 0.0
# state: action QB_SNEAK, obs: (71.0, 3, 10, 0, 0, 0), done: False, reward: 0.0
# state: action QB_SNEAK, obs: (85.0, 3, 10, 0, 0, 0), done: False, reward: 0.0
# state: action QB_SNEAK, obs: (89.0, 2, 6.0, 0, 0, 0), done: False, reward: 0.0
# state: action QB_SNEAK, obs: (90.0, 1, 5.0, 0, 0, 0), done: False, reward: 0.0
# state: action QB_SNEAK, obs: (100, 0, 5.0, 0, 1, 0), done: True, reward: 7.0
# state: action PASS, obs: (31.0, 3, 10, 0, 0, 0), done: False, reward: 0.0
# state: action QB_SNEAK, obs: (39.0, 2, 2.0, 0, 0, 0), done: False, reward: 0.0
# state: action QB_SNEAK, obs: (54.0, 3, 10, 0, 0, 0), done: False, reward: 0.0
# state: action QB_SNEAK, obs: (56.0, 2, 8.0, 0, 0, 0), done: False, reward: 0.0
# state: action QB_SNEAK, obs: (60.0, 1, 8.0, 1, 0, 0), done: True, reward: -2.8000000000000003
# state: action PASS, obs: (22.0, 2, 8.0, 0, 0, 0), done: False, reward: 0.0
# state: action PASS, obs: (22.0, 1, 8.0, 0, 0, 0), done: False, reward: 0.0
# state: action PASS, obs: (25.0, 0, 5.0, 0, 0, 0), done: True, reward: -5.25
# state: action PASS, obs: (29.0, 2, 1.0, 0, 0, 0), done: False, reward: 0.0
# state: action PASS, obs: (29.0, 1, 1.0, 0, 0, 0), done: False, reward: 0.0
# state: action QB_SNEAK, obs: (42.0, 3, 10, 0, 0, 0), done: False, reward: 0.0
# state: action QB_SNEAK, obs: (64.0, 3, 10, 0, 0, 0), done: False, reward: 0.0
# state: action QB_SNEAK, obs: (65.0, 2, 9.0, 0, 0, 0), done: False, reward: 0.0
# state: action QB_SNEAK, obs: (72.0, 1, 2.0, 0, 0, 0), done: False, reward: 0.0
# state: action QB_SNEAK, obs: (75.0, 3, 10, 0, 0, 0), done: False, reward: 0.0
# state: action QB_SNEAK, obs: (78.0, 2, 7.0, 0, 0, 0), done: False, reward: 0.0
# state: action QB_SNEAK, obs: (80.0, 1, 5.0, 0, 0, 0), done: False, reward: 0.0
# state: action QB_SNEAK, obs: (87.0, 3, 10, 0, 0, 0), done: False, reward: 0.0
# state: action QB_SNEAK, obs: (88.0, 2, 9.0, 0, 0, 0), done: False, reward: 0.0
# state: action QB_SNEAK, obs: (89.0, 1, 8.0, 0, 0, 0), done: False, reward: 0.0
# state: action QB_SNEAK, obs: (96.0, 0, 1.0, 0, 0, 0), done: True, reward: -0.28000000000000025
# state: action PASS, obs: (20.0, 2, 10.0, 0, 0, 0), done: False, reward: 0.0
