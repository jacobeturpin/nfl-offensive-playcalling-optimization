# %%
import random
import numpy as np
from keras.models import Sequential
from keras.layers.core import Dense, Activation
from keras.optimizers import Adam
import pandas as pd

random.seed(0)

class DQNAgent():
    def __init__(self, env, epsilon=1.0, alpha=0.5, gamma=0.9, time = 30000):
        self.env = env
        self.action_size = self.env.action_space.n
        self.state_size = env.observation_space
        self.memory = deque(maxlen=2000) # Record past experiences- [(state, action, reward, next_state, done)...]
        self.epsilon = epsilon   # Random exploration factor
        self.alpha = alpha       # Learning factor
        self.gamma = gamma       # Discount factor- closer to 1 learns well into distant future
        self.epsilon_min = 0.01
        self.epsilon_decay = 0.99
        self.learning = True
        self.model = self._build_model()
        
        self.time = time 
        self.time_left = time # Epsilon Decay
        self.small_decrement = (0.4 * epsilon) / (0.3 * self.time_left) # reduce epsilon
        print('HELLO')
    
    # Build Neural Net
    def _build_model(self):
#         print(type(self.state_size))
        model = Sequential()
        model.add(Dense(32, input_shape = (2,), kernel_initializer='random_uniform', activation='relu'))
        model.add(Dense(16, activation='relu'))
        model.add(Dense(self.action_size, activation='softmax'))
        model.compile(loss='binary_crossentropy', optimizer=Adam(lr=self.alpha))
        
        return model
       
#     # Remember function that stores states, actions, rewards, and done to memory
#     def remember(self, state, action, reward, next_state, done):
#         self.memory.append([state, action, reward, next_state, done])

    def choose_action(self, state):
        """
        Choose which action to take, based on the observation. 
        Uses greedy epsilon for exploration/exploitation.
        """

        # if random number > epsilon, act 'rationally'. otherwise, choose random action
        
        if np.random.rand() <= self.epsilon:
#             print(np.random.rand())
#             print(self.epsilon)
#             print('random')
#             print('-------')
            
            action = random.randrange(self.action_size)
#             print('random: ' + str(action))

            
        else:
#             print('logic')

            action_value = self.model.predict(state)
#             print(action_value)
#             print(action_value)
#             print(action_value)
#             print('-------')
            action = np.argmax(action_value[0])
#             print(action)
        
        self.update_parameters()
        return action
        
    def update_parameters(self):
        """
        Update epsilon and alpha after each action
        Set them to 0 if not learning
        """
#         print(self.time_left)
        if self.time_left > 0.9 * self.time:
            self.epsilon -= self.small_decrement
        elif self.time_left > 0.7 * self.time:
            self.epsilon -= self.small_decrement
        elif self.time_left > 0.5 * self.time:
            self.epsilon -= self.small_decrement
#             print('0.5')
        elif self.time_left > 0.3 * self.time:
#             print('0.2')
            self.epsilon -= self.small_decrement
        elif self.time_left > 0.1 * self.time:
            self.epsilon -= self.small_decrement
#         elif self.time_left < 0.05 * self.time:
#             self.epsilon = 0.000
#             self.learning = False

#         print(self.time_left)
        #         print(self.time)
        self.time_left -= 1       


    def learn(self, state, action, reward, next_state, done):
        
        
        
#         minibatch = random.sample(self.memory, batch_size)
#         print(minibatch)
        
        target = reward
#         print('STATE: ' + str(state))
#             print('next_state: ' + str(state))

#         print('target: ' + str(target))

        if not done:
            target = reward + self.gamma * np.amax(self.model.predict(next_state)[0])

#         print('target: ' + str(target))


#         print('action: ' + str(action))
#             print(self.model.predict(next_state))
#         print(np.amax(self.model.predict(next_state)[0]))

        target_f = self.model.predict(state)
#         print(target_f)
#         print('target_f: ' + str(target_f))


        target_f[0][action] = target
#         print('target_f: ' + str(target_f))
#             print('target_f: ' + str(target_f))
#         print('-------')

        self.model.fit(state, target_f, epochs=1, verbose=0)
        
        
#             print(self.time)
#         print(self.epsilon)

    def get_optimal_strategy(self):
        index = []
        for x in range(0,21):
            for y in range(1,11):
                index.append((x,y))

        df = pd.DataFrame(index = index, columns = ['Stand', 'Hit'])

        for ind in index:
            outcome = self.model.predict([np.array([ind])], batch_size=1)
            df.loc[ind, 'Stand'] = outcome[0][0]
            df.loc[ind, 'Hit'] = outcome[0][1]


        df['Optimal'] = df.apply(lambda x : 'Hit' if x['Hit'] >= x['Stand'] else 'Stand', axis=1)
        df.to_csv('optimal_policy.csv')
        return df
# Out:
# Using TensorFlow backend.

# %%
import gym
from env import NFLPlaycallingEnv
# env = gym.make('Blackjack-v0')
# env.seed(0)
env = NFLPlaycallingEnv()
# env = wrappers.Monitor(env, './logs/blackjack-Q', False, True)
import matplotlib.pyplot as plt
from collections import deque
import time

start_time = time.time()

# print(agent.model)

num_rounds = 100 # Payout calculated over num_rounds
num_samples = 50 # num_rounds simulated over num_samples

agent = DQNAgent(env=env, epsilon=1.0, alpha=0.001, gamma=0.1, time=7500)

average_payouts = []

state = env.reset()
state = np.reshape(state[0:2], [1,2])
for sample in range(num_samples):
    round = 1
    total_payout = 0 # store total payout per sample
    while round <= num_rounds:
        action = agent.choose_action(state)
        next_state, payout, done, _ = env.step(action)
        next_state = np.reshape(next_state[0:2], [1,2])

        
        total_payout += payout    
#         if agent.learning:
        agent.learn(state, action, payout, next_state, done)
        
        state = next_state
        state = np.reshape(state[0:2], [1,2])
        
        if done:
            state = env.reset() # Environment deals new cards to player and dealer
            state = np.reshape(state[0:2], [1,2])
            round += 1

    average_payouts.append(total_payout)

    if sample % 10 == 0:
        print('Done with sample: ' + str(sample) + str("   --- %s seconds ---" % (time.time() - start_time)))
        print(agent.epsilon)

print(agent.get_optimal_strategy())

# Plot payout per 1000 episodes for each value of 'sample'

plt.plot(average_payouts)           
plt.xlabel('num_samples')
plt.ylabel('payout after 1000 rounds')
plt.show()      
    
print ("Average payout after {} rounds is {}".format(num_rounds, sum(average_payouts)/(num_samples)))
# Out:
# HELLO
# action FIELD_GOAL turnover (10, 2, 10, 1, 0, 0)
# state: obs: (10, 2, 10, 1, 0, 0), done: True, reward: -6.3
# action FIELD_GOAL turnover (10, 2, 10, 1, 0, 0)
# state: obs: (10, 2, 10, 1, 0, 0), done: True, reward: -6.3
# action PUNT turnover (69.0, 2, 10, 1, 0, 0)
# state: obs: (69.0, 2, 10, 1, 0, 0), done: True, reward: -2.1700000000000004
# action QB_SNEAK continue (37.0, 3, 10, 0, 0, 0)
# state: obs: (37.0, 3, 10, 0, 0, 0), done: False, reward: 0.0
# action QB_SNEAK continue (45.0, 2, 2.0, 0, 0, 0)
# state: obs: (45.0, 2, 2.0, 0, 0, 0), done: False, reward: 0.0
# action RUN continue (48.0, 3, 10, 0, 0, 0)
# state: obs: (48.0, 3, 10, 0, 0, 0), done: False, reward: 0.0
# action QB_SNEAK continue (51.0, 2, 7.0, 0, 0, 0)
# state: obs: (51.0, 2, 7.0, 0, 0, 0), done: False, reward: 0.0
# action PASS continue (59.0, 3, 10, 0, 0, 0)
# state: obs: (59.0, 3, 10, 0, 0, 0), done: False, reward: 0.0
# action QB_SNEAK continue (83.0, 3, 10, 0, 0, 0)
# state: obs: (83.0, 3, 10, 0, 0, 0), done: False, reward: 0.0
# action PUNT turnover (83.0, 2, 10, 1, 0, 0)
# state: obs: (83.0, 2, 10, 1, 0, 0), done: True, reward: -1.1900000000000004
# action PUNT turnover (79.0, 2, 10, 1, 0, 0)
# state: obs: (79.0, 2, 10, 1, 0, 0), done: True, reward: -1.4699999999999998
# action QB_SNEAK continue (21.0, 2, 9.0, 0, 0, 0)
# state: obs: (21.0, 2, 9.0, 0, 0, 0), done: False, reward: 0.0
# action PASS continue (45.0, 3, 10, 0, 0, 0)
# state: obs: (45.0, 3, 10, 0, 0, 0), done: False, reward: 0.0
# action QB_SNEAK continue (51.0, 2, 4.0, 0, 0, 0)
# state: obs: (51.0, 2, 4.0, 0, 0, 0), done: False, reward: 0.0
# action PASS continue (51.0, 1, 4.0, 0, 0, 0)
# state: obs: (51.0, 1, 4.0, 0, 0, 0), done: False, reward: 0.0
# action QB_SNEAK continue (59.0, 3, 10, 0, 0, 0)
# state: obs: (59.0, 3, 10, 0, 0, 0), done: False, reward: 0.0
# action RUN continue (80.0, 3, 10, 0, 0, 0)
# state: obs: (80.0, 3, 10, 0, 0, 0), done: False, reward: 0.0
# action FIELD_GOAL field goal (80.0, 2, 10, 0, 0, 1)
# state: obs: (80.0, 2, 10, 0, 0, 1), done: True, reward: 3.0
# action PASS continue (26.0, 2, 4.0, 0, 0, 0)
# state: obs: (26.0, 2, 4.0, 0, 0, 0), done: False, reward: 0.0
# action PASS continue (40.0, 3, 10, 0, 0, 0)
# state: obs: (40.0, 3, 10, 0, 0, 0), done: False, reward: 0.0
# action PUNT turnover (96.0, 2, 10, 1, 0, 0)
# state: obs: (96.0, 2, 10, 1, 0, 0), done: True, reward: -0.28000000000000025
# action PASS continue (31.0, 3, 10, 0, 0, 0)
# state: obs: (31.0, 3, 10, 0, 0, 0), done: False, reward: 0.0
# action FIELD_GOAL turnover (21.0, 2, 10, 1, 0, 0)
# state: obs: (21.0, 2, 10, 1, 0, 0), done: True, reward: -5.53
# action PASS continue (28.0, 2, 2.0, 0, 0, 0)
# state: obs: (28.0, 2, 2.0, 0, 0, 0), done: False, reward: 0.0
# action QB_SNEAK continue (31.0, 3, 10, 0, 0, 0)
# state: obs: (31.0, 3, 10, 0, 0, 0), done: False, reward: 0.0
# action QB_SNEAK continue (40.0, 2, 1.0, 0, 0, 0)
# state: obs: (40.0, 2, 1.0, 0, 0, 0), done: False, reward: 0.0
# action PASS continue (40.0, 1, 1.0, 0, 0, 0)
# state: obs: (40.0, 1, 1.0, 0, 0, 0), done: False, reward: 0.0
# action PUNT turnover (80.0, 0, 1.0, 1, 0, 0)
# state: obs: (80.0, 0, 1.0, 1, 0, 0), done: True, reward: -1.3999999999999997
# action RUN continue (27.0, 2, 3.0, 0, 0, 0)
# state: obs: (27.0, 2, 3.0, 0, 0, 0), done: False, reward: 0.0
# action FIELD_GOAL turnover (17.0, 1, 3.0, 1, 0, 0)
# state: obs: (17.0, 1, 3.0, 1, 0, 0), done: True, reward: -5.81
# action QB_SNEAK continue (32.0, 3, 10, 0, 0, 0)
# state: obs: (32.0, 3, 10, 0, 0, 0), done: False, reward: 0.0
# action FIELD_GOAL turnover (22.0, 2, 10, 1, 0, 0)
# state: obs: (22.0, 2, 10, 1, 0, 0), done: True, reward: -5.46
# action PUNT turnover (64.0, 2, 10, 1, 0, 0)
# state: obs: (64.0, 2, 10, 1, 0, 0), done: True, reward: -2.52
# action PASS continue (27.0, 2, 3.0, 0, 0, 0)
# state: obs: (27.0, 2, 3.0, 0, 0, 0), done: False, reward: 0.0
# action PUNT turnover (68.0, 1, 3.0, 1, 0, 0)
# state: obs: (68.0, 1, 3.0, 1, 0, 0), done: True, reward: -2.2399999999999998
# action PUNT turnover (70.0, 2, 10, 1, 0, 0)
# state: obs: (70.0, 2, 10, 1, 0, 0), done: True, reward: -2.1000000000000005
# action QB_SNEAK continue (25.0, 2, 5.0, 0, 0, 0)
# state: obs: (25.0, 2, 5.0, 0, 0, 0), done: False, reward: 0.0
# action PUNT turnover (80.0, 1, 5.0, 1, 0, 0)
# state: obs: (80.0, 1, 5.0, 1, 0, 0), done: True, reward: -1.3999999999999997
# action QB_SNEAK continue (27.0, 2, 3.0, 0, 0, 0)
# state: obs: (27.0, 2, 3.0, 0, 0, 0), done: False, reward: 0.0
# action QB_SNEAK continue (30.0, 3, 10, 0, 0, 0)
# state: obs: (30.0, 3, 10, 0, 0, 0), done: False, reward: 0.0
# action RUN continue (28.0, 2, 12.0, 0, 0, 0)
# state: obs: (28.0, 2, 12.0, 0, 0, 0), done: False, reward: 0.0
# action QB_SNEAK continue (33.0, 1, 7.0, 0, 0, 0)
# state: obs: (33.0, 1, 7.0, 0, 0, 0), done: False, reward: 0.0
# action PASS continue (42.0, 3, 10, 0, 0, 0)
# state: obs: (42.0, 3, 10, 0, 0, 0), done: False, reward: 0.0
# action RUN continue (52.0, 3, 10, 0, 0, 0)
# state: obs: (52.0, 3, 10, 0, 0, 0), done: False, reward: 0.0
# action PASS continue (69.0, 3, 10, 0, 0, 0)
# state: obs: (69.0, 3, 10, 0, 0, 0), done: False, reward: 0.0
# action PUNT turnover (96.0, 2, 10, 1, 0, 0)
# state: obs: (96.0, 2, 10, 1, 0, 0), done: True, reward: -0.28000000000000025
# action PUNT turnover (64.0, 2, 10, 1, 0, 0)
# state: obs: (64.0, 2, 10, 1, 0, 0), done: True, reward: -2.52
# action RUN continue (29.0, 2, 1.0, 0, 0, 0)
# state: obs: (29.0, 2, 1.0, 0, 0, 0), done: False, reward: 0.0
# action PUNT turnover (85.0, 1, 1.0, 1, 0, 0)
# state: obs: (85.0, 1, 1.0, 1, 0, 0), done: True, reward: -1.0500000000000003
# action FIELD_GOAL turnover (10, 2, 10, 1, 0, 0)
# state: obs: (10, 2, 10, 1, 0, 0), done: True, reward: -6.3
# action FIELD_GOAL turnover (10, 2, 10, 1, 0, 0)
# state: obs: (10, 2, 10, 1, 0, 0), done: True, reward: -6.3
# action QB_SNEAK continue (21.0, 2, 9.0, 0, 0, 0)
# state: obs: (21.0, 2, 9.0, 0, 0, 0), done: False, reward: 0.0
# action PUNT turnover (59.0, 1, 9.0, 1, 0, 0)
# state: obs: (59.0, 1, 9.0, 1, 0, 0), done: True, reward: -2.87
# action PUNT turnover (72.0, 2, 10, 1, 0, 0)
# state: obs: (72.0, 2, 10, 1, 0, 0), done: True, reward: -1.9600000000000002
# action RUN continue (21.0, 2, 9.0, 0, 0, 0)
# state: obs: (21.0, 2, 9.0, 0, 0, 0), done: False, reward: 0.0
# action QB_SNEAK continue (23.0, 1, 7.0, 0, 0, 0)
# state: obs: (23.0, 1, 7.0, 0, 0, 0), done: False, reward: 0.0
# action RUN turnover (25.0, 0, 5.0, 0, 0, 0)
# state: obs: (25.0, 0, 5.0, 0, 0, 0), done: True, reward: -5.25
# action RUN continue (22.0, 2, 8.0, 0, 0, 0)
# state: obs: (22.0, 2, 8.0, 0, 0, 0), done: False, reward: 0.0
# action PASS continue (22.0, 1, 8.0, 0, 0, 0)
# state: obs: (22.0, 1, 8.0, 0, 0, 0), done: False, reward: 0.0
# action RUN continue (31.0, 3, 10, 0, 0, 0)
# state: obs: (31.0, 3, 10, 0, 0, 0), done: False, reward: 0.0
# action RUN continue (29.0, 2, 12.0, 0, 0, 0)
# state: obs: (29.0, 2, 12.0, 0, 0, 0), done: False, reward: 0.0
# action PUNT turnover (81.0, 1, 12.0, 1, 0, 0)
# state: obs: (81.0, 1, 12.0, 1, 0, 0), done: True, reward: -1.3299999999999996
# action PUNT turnover (72.0, 2, 10, 1, 0, 0)
# state: obs: (72.0, 2, 10, 1, 0, 0), done: True, reward: -1.9600000000000002
# action PASS continue (13.0, 2, 17.0, 0, 0, 0)
# state: obs: (13.0, 2, 17.0, 0, 0, 0), done: False, reward: 0.0
# action RUN continue (17.0, 1, 13.0, 0, 0, 0)
# state: obs: (17.0, 1, 13.0, 0, 0, 0), done: False, reward: 0.0
# action PUNT turnover (55.0, 0, 13.0, 1, 0, 0)
# state: obs: (55.0, 0, 13.0, 1, 0, 0), done: True, reward: -3.1499999999999995
# action PASS continue (20.0, 2, 10.0, 0, 0, 0)
# state: obs: (20.0, 2, 10.0, 0, 0, 0), done: False, reward: 0.0
# action PASS continue (14.0, 1, 16.0, 0, 0, 0)
# state: obs: (14.0, 1, 16.0, 0, 0, 0), done: False, reward: 0.0
# action PASS turnover (14.0, 0, 16.0, 0, 0, 0)
# state: obs: (14.0, 0, 16.0, 0, 0, 0), done: True, reward: -6.02
# action RUN continue (25.0, 2, 5.0, 0, 0, 0)
# state: obs: (25.0, 2, 5.0, 0, 0, 0), done: False, reward: 0.0
# action FIELD_GOAL turnover (15.0, 1, 5.0, 1, 0, 0)
# state: obs: (15.0, 1, 5.0, 1, 0, 0), done: True, reward: -5.95
# action PASS continue (53.0, 3, 10, 0, 0, 0)
# state: obs: (53.0, 3, 10, 0, 0, 0), done: False, reward: 0.0
# action PASS continue (59.0, 2, 4.0, 0, 0, 0)
# state: obs: (59.0, 2, 4.0, 0, 0, 0), done: False, reward: 0.0
# action PUNT turnover (84.0, 1, 4.0, 1, 0, 0)
# state: obs: (84.0, 1, 4.0, 1, 0, 0), done: True, reward: -1.12
# action QB_SNEAK continue (21.0, 2, 9.0, 0, 0, 0)
# state: obs: (21.0, 2, 9.0, 0, 0, 0), done: False, reward: 0.0
# action PASS continue (30.0, 3, 10, 0, 0, 0)
# state: obs: (30.0, 3, 10, 0, 0, 0), done: False, reward: 0.0
# action QB_SNEAK continue (35.0, 2, 5.0, 0, 0, 0)
# state: obs: (35.0, 2, 5.0, 0, 0, 0), done: False, reward: 0.0
# action PASS continue (40.0, 3, 10, 0, 0, 0)
# state: obs: (40.0, 3, 10, 0, 0, 0), done: False, reward: 0.0
# action PASS continue (48.0, 2, 2.0, 0, 0, 0)
# state: obs: (48.0, 2, 2.0, 0, 0, 0), done: False, reward: 0.0
# action FIELD_GOAL turnover (38.0, 1, 2.0, 1, 0, 0)
# state: obs: (38.0, 1, 2.0, 1, 0, 0), done: True, reward: -4.34
# action QB_SNEAK continue (33.0, 3, 10, 0, 0, 0)
# state: obs: (33.0, 3, 10, 0, 0, 0), done: False, reward: 0.0
# action FIELD_GOAL turnover (23.0, 2, 10, 1, 0, 0)
# state: obs: (23.0, 2, 10, 1, 0, 0), done: True, reward: -5.390000000000001
# action PUNT turnover (61.0, 2, 10, 1, 0, 0)
# state: obs: (61.0, 2, 10, 1, 0, 0), done: True, reward: -2.73
# action RUN continue (40.0, 3, 10, 0, 0, 0)
# state: obs: (40.0, 3, 10, 0, 0, 0), done: False, reward: 0.0
# action PASS continue (55.0, 3, 10, 0, 0, 0)
# state: obs: (55.0, 3, 10, 0, 0, 0), done: False, reward: 0.0
# action RUN continue (64.0, 2, 1.0, 0, 0, 0)
# state: obs: (64.0, 2, 1.0, 0, 0, 0), done: False, reward: 0.0
# action QB_SNEAK continue (70.0, 3, 10, 0, 0, 0)
# state: obs: (70.0, 3, 10, 0, 0, 0), done: False, reward: 0.0
# action PASS continue (77.0, 2, 3.0, 0, 0, 0)
# state: obs: (77.0, 2, 3.0, 0, 0, 0), done: False, reward: 0.0
# action FIELD_GOAL field goal (77.0, 1, 3.0, 0, 0, 1)
# state: obs: (77.0, 1, 3.0, 0, 0, 1), done: True, reward: 3.0
# action PASS continue (25.0, 2, 5.0, 0, 0, 0)
# state: obs: (25.0, 2, 5.0, 0, 0, 0), done: False, reward: 0.0
# action FIELD_GOAL turnover (15.0, 1, 5.0, 1, 0, 0)
# state: obs: (15.0, 1, 5.0, 1, 0, 0), done: True, reward: -5.95
# action PUNT turnover (80.0, 2, 10, 1, 0, 0)
# state: obs: (80.0, 2, 10, 1, 0, 0), done: True, reward: -1.3999999999999997
# action QB_SNEAK continue (25.0, 2, 5.0, 0, 0, 0)
# state: obs: (25.0, 2, 5.0, 0, 0, 0), done: False, reward: 0.0
# action QB_SNEAK continue (27.0, 1, 3.0, 0, 0, 0)
# state: obs: (27.0, 1, 3.0, 0, 0, 0), done: False, reward: 0.0
# action PASS continue (31.0, 3, 10, 0, 0, 0)
# state: obs: (31.0, 3, 10, 0, 0, 0), done: False, reward: 0.0
# action PASS continue (31.0, 2, 10.0, 0, 0, 0)
# state: obs: (31.0, 2, 10.0, 0, 0, 0), done: False, reward: 0.0
# action PASS continue (37.0, 1, 4.0, 0, 0, 0)
# state: obs: (37.0, 1, 4.0, 0, 0, 0), done: False, reward: 0.0
# action RUN turnover (38.0, 0, 3.0, 0, 0, 0)
# state: obs: (38.0, 0, 3.0, 0, 0, 0), done: True, reward: -4.34
# action FIELD_GOAL turnover (10, 2, 10, 1, 0, 0)
# state: obs: (10, 2, 10, 1, 0, 0), done: True, reward: -6.3
# action QB_SNEAK continue (28.0, 2, 2.0, 0, 0, 0)
# state: obs: (28.0, 2, 2.0, 0, 0, 0), done: False, reward: 0.0
# action PUNT turnover (89.0, 1, 2.0, 1, 0, 0)
# state: obs: (89.0, 1, 2.0, 1, 0, 0), done: True, reward: -0.7699999999999999
# action PUNT turnover (60.0, 2, 10, 1, 0, 0)
# state: obs: (60.0, 2, 10, 1, 0, 0), done: True, reward: -2.8000000000000003
# action QB_SNEAK continue (25.0, 2, 5.0, 0, 0, 0)
# state: obs: (25.0, 2, 5.0, 0, 0, 0), done: False, reward: 0.0
# action FIELD_GOAL turnover (15.0, 1, 5.0, 1, 0, 0)
# state: obs: (15.0, 1, 5.0, 1, 0, 0), done: True, reward: -5.95
# action PASS continue (8.0, 2, 22.0, 0, 0, 0)
# state: obs: (8.0, 2, 22.0, 0, 0, 0), done: False, reward: 0.0
# action RUN continue (13.0, 1, 17.0, 0, 0, 0)
# state: obs: (13.0, 1, 17.0, 0, 0, 0), done: False, reward: 0.0
# action RUN turnover (14.0, 0, 16.0, 0, 0, 0)
# state: obs: (14.0, 0, 16.0, 0, 0, 0), done: True, reward: -6.02
# action FIELD_GOAL turnover (10, 2, 10, 1, 0, 0)
# state: obs: (10, 2, 10, 1, 0, 0), done: True, reward: -6.3
# action PUNT turnover (79.0, 2, 10, 1, 0, 0)
# state: obs: (79.0, 2, 10, 1, 0, 0), done: True, reward: -1.4699999999999998
# action PASS continue (23.0, 2, 7.0, 0, 0, 0)
# state: obs: (23.0, 2, 7.0, 0, 0, 0), done: False, reward: 0.0
# action PUNT turnover (70.0, 1, 7.0, 1, 0, 0)
# state: obs: (70.0, 1, 7.0, 1, 0, 0), done: True, reward: -2.1000000000000005
# action PASS continue (20.0, 2, 10.0, 0, 0, 0)
# state: obs: (20.0, 2, 10.0, 0, 0, 0), done: False, reward: 0.0
# action PASS continue (20.0, 1, 10.0, 0, 0, 0)
# state: obs: (20.0, 1, 10.0, 0, 0, 0), done: False, reward: 0.0
# action RUN turnover (23.0, 0, 7.0, 0, 0, 0)
# state: obs: (23.0, 0, 7.0, 0, 0, 0), done: True, reward: -5.390000000000001
# action FIELD_GOAL turnover (10, 2, 10, 1, 0, 0)
# state: obs: (10, 2, 10, 1, 0, 0), done: True, reward: -6.3
# action PUNT turnover (75.0, 2, 10, 1, 0, 0)
# state: obs: (75.0, 2, 10, 1, 0, 0), done: True, reward: -1.75
# action PASS continue (25.0, 2, 5.0, 0, 0, 0)
# state: obs: (25.0, 2, 5.0, 0, 0, 0), done: False, reward: 0.0
# action QB_SNEAK continue (36.0, 3, 10, 0, 0, 0)
# state: obs: (36.0, 3, 10, 0, 0, 0), done: False, reward: 0.0
# action PASS continue (51.0, 3, 10, 0, 0, 0)
# state: obs: (51.0, 3, 10, 0, 0, 0), done: False, reward: 0.0
# action FIELD_GOAL turnover (51.0, 2, 10, 1, 0, 0)
# state: obs: (51.0, 2, 10, 1, 0, 0), done: True, reward: -3.4299999999999997
# action PASS continue (36.0, 3, 10, 0, 0, 0)
# state: obs: (36.0, 3, 10, 0, 0, 0), done: False, reward: 0.0
# action RUN continue (71.0, 3, 10, 0, 0, 0)
# state: obs: (71.0, 3, 10, 0, 0, 0), done: False, reward: 0.0
# action FIELD_GOAL turnover (71.0, 2, 10, 1, 0, 0)
# state: obs: (71.0, 2, 10, 1, 0, 0), done: True, reward: -2.0300000000000002
# action FIELD_GOAL turnover (10, 2, 10, 1, 0, 0)
# state: obs: (10, 2, 10, 1, 0, 0), done: True, reward: -6.3
# action RUN continue (16.0, 2, 14.0, 0, 0, 0)
# state: obs: (16.0, 2, 14.0, 0, 0, 0), done: False, reward: 0.0
# action PASS turnover (16.0, 1, 14.0, 1, 0, 0)
# state: obs: (16.0, 1, 14.0, 1, 0, 0), done: True, reward: -5.88
# action PUNT turnover (72.0, 2, 10, 1, 0, 0)
# state: obs: (72.0, 2, 10, 1, 0, 0), done: True, reward: -1.9600000000000002
# action QB_SNEAK continue (22.0, 2, 8.0, 0, 0, 0)
# state: obs: (22.0, 2, 8.0, 0, 0, 0), done: False, reward: 0.0
# action PUNT turnover (73.0, 1, 8.0, 1, 0, 0)
# state: obs: (73.0, 1, 8.0, 1, 0, 0), done: True, reward: -1.8900000000000001
# action QB_SNEAK continue (23.0, 2, 7.0, 0, 0, 0)
# state: obs: (23.0, 2, 7.0, 0, 0, 0), done: False, reward: 0.0
# action RUN continue (23.0, 1, 7.0, 0, 0, 0)
# state: obs: (23.0, 1, 7.0, 0, 0, 0), done: False, reward: 0.0
# action FIELD_GOAL turnover (13.0, 0, 7.0, 1, 0, 0)
# state: obs: (13.0, 0, 7.0, 1, 0, 0), done: True, reward: -6.09
# action PASS continue (20.0, 2, 10.0, 0, 0, 0)
# state: obs: (20.0, 2, 10.0, 0, 0, 0), done: False, reward: 0.0
# action FIELD_GOAL turnover (10.0, 1, 10.0, 1, 0, 0)
# state: obs: (10.0, 1, 10.0, 1, 0, 0), done: True, reward: -6.3
# action PASS continue (38.0, 3, 10, 0, 0, 0)
# state: obs: (38.0, 3, 10, 0, 0, 0), done: False, reward: 0.0
# action RUN continue (43.0, 2, 5.0, 0, 0, 0)
# state: obs: (43.0, 2, 5.0, 0, 0, 0), done: False, reward: 0.0
# action QB_SNEAK continue (45.0, 1, 3.0, 0, 0, 0)
# state: obs: (45.0, 1, 3.0, 0, 0, 0), done: False, reward: 0.0
# action RUN turnover (46.0, 0, 2.0, 0, 0, 0)
# state: obs: (46.0, 0, 2.0, 0, 0, 0), done: True, reward: -3.7800000000000002
# action PASS continue (15.0, 2, 15.0, 0, 0, 0)
# state: obs: (15.0, 2, 15.0, 0, 0, 0), done: False, reward: 0.0
# action RUN continue (20.0, 1, 10.0, 0, 0, 0)
# state: obs: (20.0, 1, 10.0, 0, 0, 0), done: False, reward: 0.0
# action PUNT turnover (65.0, 0, 10.0, 1, 0, 0)
# state: obs: (65.0, 0, 10.0, 1, 0, 0), done: True, reward: -2.4499999999999997
# action QB_SNEAK continue (35.0, 3, 10, 0, 0, 0)
# state: obs: (35.0, 3, 10, 0, 0, 0), done: False, reward: 0.0
# action PASS continue (52.0, 3, 10, 0, 0, 0)
# state: obs: (52.0, 3, 10, 0, 0, 0), done: False, reward: 0.0
# action PUNT turnover (90.0, 2, 10, 1, 0, 0)
# state: obs: (90.0, 2, 10, 1, 0, 0), done: True, reward: -0.6999999999999998
# action FIELD_GOAL turnover (10, 2, 10, 1, 0, 0)
# state: obs: (10, 2, 10, 1, 0, 0), done: True, reward: -6.3
# action QB_SNEAK continue (32.0, 3, 10, 0, 0, 0)
# state: obs: (32.0, 3, 10, 0, 0, 0), done: False, reward: 0.0
# action RUN continue (33.0, 2, 9.0, 0, 0, 0)
# state: obs: (33.0, 2, 9.0, 0, 0, 0), done: False, reward: 0.0
# action PUNT turnover (77.0, 1, 9.0, 1, 0, 0)
# state: obs: (77.0, 1, 9.0, 1, 0, 0), done: True, reward: -1.6099999999999999
# action RUN continue (20.0, 2, 10.0, 0, 0, 0)
# state: obs: (20.0, 2, 10.0, 0, 0, 0), done: False, reward: 0.0
# action QB_SNEAK continue (24.0, 1, 6.0, 0, 0, 0)
# state: obs: (24.0, 1, 6.0, 0, 0, 0), done: False, reward: 0.0
# action QB_SNEAK continue (36.0, 3, 10, 0, 0, 0)
# state: obs: (36.0, 3, 10, 0, 0, 0), done: False, reward: 0.0
# action QB_SNEAK continue (48.0, 3, 10, 0, 0, 0)
# state: obs: (48.0, 3, 10, 0, 0, 0), done: False, reward: 0.0
# action PASS continue (43.0, 2, 15.0, 0, 0, 0)
# state: obs: (43.0, 2, 15.0, 0, 0, 0), done: False, reward: 0.0
# action RUN continue (43.0, 1, 15.0, 0, 0, 0)
# state: obs: (43.0, 1, 15.0, 0, 0, 0), done: False, reward: 0.0
# action PUNT turnover (83.0, 0, 15.0, 1, 0, 0)
# state: obs: (83.0, 0, 15.0, 1, 0, 0), done: True, reward: -1.1900000000000004
# action FIELD_GOAL turnover (10, 2, 10, 1, 0, 0)
# state: obs: (10, 2, 10, 1, 0, 0), done: True, reward: -6.3
# action RUN continue (22.0, 2, 8.0, 0, 0, 0)
# state: obs: (22.0, 2, 8.0, 0, 0, 0), done: False, reward: 0.0
# action FIELD_GOAL turnover (12.0, 1, 8.0, 1, 0, 0)
# state: obs: (12.0, 1, 8.0, 1, 0, 0), done: True, reward: -6.16
# action PASS continue (20.0, 2, 10.0, 0, 0, 0)
# state: obs: (20.0, 2, 10.0, 0, 0, 0), done: False, reward: 0.0
# action PUNT turnover (74.0, 1, 10.0, 1, 0, 0)
# state: obs: (74.0, 1, 10.0, 1, 0, 0), done: True, reward: -1.82
# action QB_SNEAK continue (25.0, 2, 5.0, 0, 0, 0)
# state: obs: (25.0, 2, 5.0, 0, 0, 0), done: False, reward: 0.0
# action QB_SNEAK continue (28.0, 1, 2.0, 0, 0, 0)
# state: obs: (28.0, 1, 2.0, 0, 0, 0), done: False, reward: 0.0
# action PASS turnover (28.0, 0, 2.0, 0, 0, 0)
# state: obs: (28.0, 0, 2.0, 0, 0, 0), done: True, reward: -5.04
# action FIELD_GOAL turnover (10, 2, 10, 1, 0, 0)
# state: obs: (10, 2, 10, 1, 0, 0), done: True, reward: -6.3
# action QB_SNEAK continue (22.0, 2, 8.0, 0, 0, 0)
# state: obs: (22.0, 2, 8.0, 0, 0, 0), done: False, reward: 0.0
# action PASS continue (31.0, 3, 10, 0, 0, 0)
# state: obs: (31.0, 3, 10, 0, 0, 0), done: False, reward: 0.0
# action FIELD_GOAL turnover (21.0, 2, 10, 1, 0, 0)
# state: obs: (21.0, 2, 10, 1, 0, 0), done: True, reward: -5.53
# action QB_SNEAK continue (29.0, 2, 1.0, 0, 0, 0)
# state: obs: (29.0, 2, 1.0, 0, 0, 0), done: False, reward: 0.0
# action RUN continue (42.0, 3, 10, 0, 0, 0)
# state: obs: (42.0, 3, 10, 0, 0, 0), done: False, reward: 0.0
# action QB_SNEAK continue (49.0, 2, 3.0, 0, 0, 0)
# state: obs: (49.0, 2, 3.0, 0, 0, 0), done: False, reward: 0.0
# action FIELD_GOAL turnover (39.0, 1, 3.0, 1, 0, 0)
# state: obs: (39.0, 1, 3.0, 1, 0, 0), done: True, reward: -4.27
# action PASS continue (18.0, 2, 12.0, 0, 0, 0)
# state: obs: (18.0, 2, 12.0, 0, 0, 0), done: False, reward: 0.0
# action PASS continue (18.0, 1, 12.0, 0, 0, 0)
# state: obs: (18.0, 1, 12.0, 0, 0, 0), done: False, reward: 0.0
# action RUN turnover (17.0, 0, 13.0, 0, 0, 0)
# state: obs: (17.0, 0, 13.0, 0, 0, 0), done: True, reward: -5.81
# action PASS continue (20.0, 2, 10.0, 0, 0, 0)
# state: obs: (20.0, 2, 10.0, 0, 0, 0), done: False, reward: 0.0
# action PUNT turnover (70.0, 1, 10.0, 1, 0, 0)
# state: obs: (70.0, 1, 10.0, 1, 0, 0), done: True, reward: -2.1000000000000005
# action FIELD_GOAL turnover (10, 2, 10, 1, 0, 0)
# state: obs: (10, 2, 10, 1, 0, 0), done: True, reward: -6.3
# action PUNT turnover (74.0, 2, 10, 1, 0, 0)
# state: obs: (74.0, 2, 10, 1, 0, 0), done: True, reward: -1.82
# action RUN continue (23.0, 2, 7.0, 0, 0, 0)
# state: obs: (23.0, 2, 7.0, 0, 0, 0), done: False, reward: 0.0
# action QB_SNEAK continue (26.0, 1, 4.0, 0, 0, 0)
# state: obs: (26.0, 1, 4.0, 0, 0, 0), done: False, reward: 0.0
# action QB_SNEAK continue (33.0, 3, 10, 0, 0, 0)
# state: obs: (33.0, 3, 10, 0, 0, 0), done: False, reward: 0.0
# action RUN continue (36.0, 2, 7.0, 0, 0, 0)
# state: obs: (36.0, 2, 7.0, 0, 0, 0), done: False, reward: 0.0
# action QB_SNEAK continue (38.0, 1, 5.0, 0, 0, 0)
# state: obs: (38.0, 1, 5.0, 0, 0, 0), done: False, reward: 0.0
# action PASS continue (60.0, 3, 10, 0, 0, 0)
# state: obs: (60.0, 3, 10, 0, 0, 0), done: False, reward: 0.0
# action FIELD_GOAL turnover (60.0, 2, 10, 1, 0, 0)
# state: obs: (60.0, 2, 10, 1, 0, 0), done: True, reward: -2.8000000000000003
# action RUN continue (20.0, 2, 10.0, 0, 0, 0)
# state: obs: (20.0, 2, 10.0, 0, 0, 0), done: False, reward: 0.0
# action FIELD_GOAL turnover (10.0, 1, 10.0, 1, 0, 0)
# state: obs: (10.0, 1, 10.0, 1, 0, 0), done: True, reward: -6.3
# action PASS td (100, 2, 10, 0, 1, 0)
# state: obs: (100, 2, 10, 0, 1, 0), done: True, reward: 7.0
# action RUN continue (24.0, 2, 6.0, 0, 0, 0)
# state: obs: (24.0, 2, 6.0, 0, 0, 0), done: False, reward: 0.0
# action PASS continue (24.0, 1, 6.0, 0, 0, 0)
# state: obs: (24.0, 1, 6.0, 0, 0, 0), done: False, reward: 0.0
# action FIELD_GOAL turnover (14.0, 0, 6.0, 1, 0, 0)
# state: obs: (14.0, 0, 6.0, 1, 0, 0), done: True, reward: -6.02
# action RUN continue (20.0, 2, 10.0, 0, 0, 0)
# state: obs: (20.0, 2, 10.0, 0, 0, 0), done: False, reward: 0.0
# action PUNT turnover (97.0, 1, 10.0, 1, 0, 0)
# state: obs: (97.0, 1, 10.0, 1, 0, 0), done: True, reward: -0.2100000000000002
# action RUN continue (24.0, 2, 6.0, 0, 0, 0)
# state: obs: (24.0, 2, 6.0, 0, 0, 0), done: False, reward: 0.0
# action FIELD_GOAL turnover (14.0, 1, 6.0, 1, 0, 0)
# state: obs: (14.0, 1, 6.0, 1, 0, 0), done: True, reward: -6.02
# action FIELD_GOAL turnover (10, 2, 10, 1, 0, 0)
# state: obs: (10, 2, 10, 1, 0, 0), done: True, reward: -6.3
# action QB_SNEAK continue (31.0, 3, 10, 0, 0, 0)
# state: obs: (31.0, 3, 10, 0, 0, 0), done: False, reward: 0.0
# action FIELD_GOAL turnover (21.0, 2, 10, 1, 0, 0)
# state: obs: (21.0, 2, 10, 1, 0, 0), done: True, reward: -5.53
# action RUN continue (24.0, 2, 6.0, 0, 0, 0)
# state: obs: (24.0, 2, 6.0, 0, 0, 0), done: False, reward: 0.0
# action RUN continue (20.0, 1, 10.0, 0, 0, 0)
# state: obs: (20.0, 1, 10.0, 0, 0, 0), done: False, reward: 0.0
# action QB_SNEAK continue (30.0, 3, 10, 0, 0, 0)
# state: obs: (30.0, 3, 10, 0, 0, 0), done: False, reward: 0.0
# action PASS continue (36.0, 2, 4.0, 0, 0, 0)
# state: obs: (36.0, 2, 4.0, 0, 0, 0), done: False, reward: 0.0
# action QB_SNEAK continue (44.0, 3, 10, 0, 0, 0)
# state: obs: (44.0, 3, 10, 0, 0, 0), done: False, reward: 0.0
# action RUN continue (53.0, 2, 1.0, 0, 0, 0)
# state: obs: (53.0, 2, 1.0, 0, 0, 0), done: False, reward: 0.0
# action PUNT turnover (87.0, 1, 1.0, 1, 0, 0)
# state: obs: (87.0, 1, 1.0, 1, 0, 0), done: True, reward: -0.91
# action FIELD_GOAL turnover (10, 2, 10, 1, 0, 0)
# state: obs: (10, 2, 10, 1, 0, 0), done: True, reward: -6.3
# action PASS continue (26.0, 2, 4.0, 0, 0, 0)
# state: obs: (26.0, 2, 4.0, 0, 0, 0), done: False, reward: 0.0
# action PASS continue (24.0, 1, 6.0, 0, 0, 0)
# state: obs: (24.0, 1, 6.0, 0, 0, 0), done: False, reward: 0.0
# action RUN turnover (22.0, 0, 8.0, 0, 0, 0)
# state: obs: (22.0, 0, 8.0, 0, 0, 0), done: True, reward: -5.46
# action PASS continue (33.0, 3, 10, 0, 0, 0)
# state: obs: (33.0, 3, 10, 0, 0, 0), done: False, reward: 0.0
# action FIELD_GOAL turnover (23.0, 2, 10, 1, 0, 0)
# state: obs: (23.0, 2, 10, 1, 0, 0), done: True, reward: -5.390000000000001
# action RUN continue (27.0, 2, 3.0, 0, 0, 0)
# state: obs: (27.0, 2, 3.0, 0, 0, 0), done: False, reward: 0.0
# action FIELD_GOAL turnover (17.0, 1, 3.0, 1, 0, 0)
# state: obs: (17.0, 1, 3.0, 1, 0, 0), done: True, reward: -5.81
# action PUNT turnover (67.0, 2, 10, 1, 0, 0)
# state: obs: (67.0, 2, 10, 1, 0, 0), done: True, reward: -2.3099999999999996
# action PUNT turnover (70.0, 2, 10, 1, 0, 0)
# state: obs: (70.0, 2, 10, 1, 0, 0), done: True, reward: -2.1000000000000005
# action PUNT turnover (57.0, 2, 10, 1, 0, 0)
# state: obs: (57.0, 2, 10, 1, 0, 0), done: True, reward: -3.0100000000000002
# action PUNT turnover (75.0, 2, 10, 1, 0, 0)
# state: obs: (75.0, 2, 10, 1, 0, 0), done: True, reward: -1.75
# action PASS continue (32.0, 3, 10, 0, 0, 0)
# state: obs: (32.0, 3, 10, 0, 0, 0), done: False, reward: 0.0
# action RUN continue (34.0, 2, 8.0, 0, 0, 0)
# state: obs: (34.0, 2, 8.0, 0, 0, 0), done: False, reward: 0.0
# action PUNT turnover (80.0, 1, 8.0, 1, 0, 0)
# state: obs: (80.0, 1, 8.0, 1, 0, 0), done: True, reward: -1.3999999999999997
# action FIELD_GOAL turnover (10, 2, 10, 1, 0, 0)
# state: obs: (10, 2, 10, 1, 0, 0), done: True, reward: -6.3
# action FIELD_GOAL turnover (10, 2, 10, 1, 0, 0)
# state: obs: (10, 2, 10, 1, 0, 0), done: True, reward: -6.3
# action RUN continue (29.0, 2, 1.0, 0, 0, 0)
# state: obs: (29.0, 2, 1.0, 0, 0, 0), done: False, reward: 0.0
# action PASS continue (38.0, 3, 10, 0, 0, 0)
# state: obs: (38.0, 3, 10, 0, 0, 0), done: False, reward: 0.0
# action PASS continue (50.0, 3, 10, 0, 0, 0)
# state: obs: (50.0, 3, 10, 0, 0, 0), done: False, reward: 0.0
# action QB_SNEAK continue (57.0, 2, 3.0, 0, 0, 0)
# state: obs: (57.0, 2, 3.0, 0, 0, 0), done: False, reward: 0.0
# action QB_SNEAK continue (60.0, 3, 10, 0, 0, 0)
# state: obs: (60.0, 3, 10, 0, 0, 0), done: False, reward: 0.0
# action FIELD_GOAL turnover (60.0, 2, 10, 1, 0, 0)
# state: obs: (60.0, 2, 10, 1, 0, 0), done: True, reward: -2.8000000000000003
# action QB_SNEAK continue (29.0, 2, 1.0, 0, 0, 0)
# state: obs: (29.0, 2, 1.0, 0, 0, 0), done: False, reward: 0.0
# action FIELD_GOAL turnover (19.0, 1, 1.0, 1, 0, 0)
# state: obs: (19.0, 1, 1.0, 1, 0, 0), done: True, reward: -5.67
# action PASS continue (20.0, 2, 10.0, 0, 0, 0)
# state: obs: (20.0, 2, 10.0, 0, 0, 0), done: False, reward: 0.0
# action RUN continue (21.0, 1, 9.0, 0, 0, 0)
# state: obs: (21.0, 1, 9.0, 0, 0, 0), done: False, reward: 0.0
# action QB_SNEAK turnover (22.0, 0, 8.0, 0, 0, 0)
# state: obs: (22.0, 0, 8.0, 0, 0, 0), done: True, reward: -5.46
# action PASS continue (25.0, 2, 5.0, 0, 0, 0)
# state: obs: (25.0, 2, 5.0, 0, 0, 0), done: False, reward: 0.0
# action RUN continue (28.0, 1, 2.0, 0, 0, 0)
# state: obs: (28.0, 1, 2.0, 0, 0, 0), done: False, reward: 0.0
# action PUNT turnover (80.0, 0, 2.0, 1, 0, 0)
# state: obs: (80.0, 0, 2.0, 1, 0, 0), done: True, reward: -1.3999999999999997
# action RUN continue (28.0, 2, 2.0, 0, 0, 0)
# state: obs: (28.0, 2, 2.0, 0, 0, 0), done: False, reward: 0.0
# action QB_SNEAK continue (33.0, 3, 10, 0, 0, 0)
# state: obs: (33.0, 3, 10, 0, 0, 0), done: False, reward: 0.0
# action PUNT turnover (80.0, 2, 10, 1, 0, 0)
# state: obs: (80.0, 2, 10, 1, 0, 0), done: True, reward: -1.3999999999999997
# action FIELD_GOAL turnover (10, 2, 10, 1, 0, 0)
# state: obs: (10, 2, 10, 1, 0, 0), done: True, reward: -6.3
# action FIELD_GOAL turnover (10, 2, 10, 1, 0, 0)
# state: obs: (10, 2, 10, 1, 0, 0), done: True, reward: -6.3
# action PASS continue (14.0, 2, 16.0, 0, 0, 0)
# state: obs: (14.0, 2, 16.0, 0, 0, 0), done: False, reward: 0.0
# action PUNT turnover (54.0, 1, 16.0, 1, 0, 0)
# state: obs: (54.0, 1, 16.0, 1, 0, 0), done: True, reward: -3.2199999999999998
# Done with sample: 0   --- 88.68995141983032 seconds ---
# 0.9567999999999868
# action QB_SNEAK continue (21.0, 2, 9.0, 0, 0, 0)
# state: obs: (21.0, 2, 9.0, 0, 0, 0), done: False, reward: 0.0
# action PUNT turnover (72.0, 1, 9.0, 1, 0, 0)
# state: obs: (72.0, 1, 9.0, 1, 0, 0), done: True, reward: -1.9600000000000002
# action RUN continue (22.0, 2, 8.0, 0, 0, 0)
# state: obs: (22.0, 2, 8.0, 0, 0, 0), done: False, reward: 0.0
# action FIELD_GOAL turnover (12.0, 1, 8.0, 1, 0, 0)
# state: obs: (12.0, 1, 8.0, 1, 0, 0), done: True, reward: -6.16
# action PASS continue (28.0, 2, 2.0, 0, 0, 0)
# state: obs: (28.0, 2, 2.0, 0, 0, 0), done: False, reward: 0.0
# action FIELD_GOAL turnover (18.0, 1, 2.0, 1, 0, 0)
# state: obs: (18.0, 1, 2.0, 1, 0, 0), done: True, reward: -5.74
# action QB_SNEAK continue (28.0, 2, 2.0, 0, 0, 0)
# state: obs: (28.0, 2, 2.0, 0, 0, 0), done: False, reward: 0.0
# action PUNT turnover (71.0, 1, 2.0, 1, 0, 0)
# state: obs: (71.0, 1, 2.0, 1, 0, 0), done: True, reward: -2.0300000000000002
# action RUN continue (38.0, 3, 10, 0, 0, 0)
# state: obs: (38.0, 3, 10, 0, 0, 0), done: False, reward: 0.0
# action FIELD_GOAL turnover (28.0, 2, 10, 1, 0, 0)
# state: obs: (28.0, 2, 10, 1, 0, 0), done: True, reward: -5.04
# action PASS continue (26.0, 2, 4.0, 0, 0, 0)
# state: obs: (26.0, 2, 4.0, 0, 0, 0), done: False, reward: 0.0
# action RUN continue (24.0, 1, 6.0, 0, 0, 0)
# state: obs: (24.0, 1, 6.0, 0, 0, 0), done: False, reward: 0.0
# action FIELD_GOAL turnover (14.0, 0, 6.0, 1, 0, 0)
# state: obs: (14.0, 0, 6.0, 1, 0, 0), done: True, reward: -6.02
# action RUN continue (23.0, 2, 7.0, 0, 0, 0)
# state: obs: (23.0, 2, 7.0, 0, 0, 0), done: False, reward: 0.0
# action QB_SNEAK continue (34.0, 3, 10, 0, 0, 0)
# state: obs: (34.0, 3, 10, 0, 0, 0), done: False, reward: 0.0
# action PASS continue (80.0, 3, 10, 0, 0, 0)
# state: obs: (80.0, 3, 10, 0, 0, 0), done: False, reward: 0.0
# action PASS continue (83.0, 2, 7.0, 0, 0, 0)
# state: obs: (83.0, 2, 7.0, 0, 0, 0), done: False, reward: 0.0
# action PASS td (100, 1, 7.0, 0, 1, 0)
# state: obs: (100, 1, 7.0, 0, 1, 0), done: True, reward: 7.0
# action PUNT turnover (71.0, 2, 10, 1, 0, 0)
# state: obs: (71.0, 2, 10, 1, 0, 0), done: True, reward: -2.0300000000000002
# action RUN continue (21.0, 2, 9.0, 0, 0, 0)
# state: obs: (21.0, 2, 9.0, 0, 0, 0), done: False, reward: 0.0
# action PUNT turnover (74.0, 1, 9.0, 1, 0, 0)
# state: obs: (74.0, 1, 9.0, 1, 0, 0), done: True, reward: -1.82
# action FIELD_GOAL turnover (10, 2, 10, 1, 0, 0)
# state: obs: (10, 2, 10, 1, 0, 0), done: True, reward: -6.3
# action PASS continue (20.0, 2, 10.0, 0, 0, 0)
# state: obs: (20.0, 2, 10.0, 0, 0, 0), done: False, reward: 0.0
# action PUNT turnover (68.0, 1, 10.0, 1, 0, 0)
# state: obs: (68.0, 1, 10.0, 1, 0, 0), done: True, reward: -2.2399999999999998
# action PASS continue (52.0, 3, 10, 0, 0, 0)
# state: obs: (52.0, 3, 10, 0, 0, 0), done: False, reward: 0.0
# action FIELD_GOAL turnover (52.0, 2, 10, 1, 0, 0)
# state: obs: (52.0, 2, 10, 1, 0, 0), done: True, reward: -3.36
# action FIELD_GOAL turnover (10, 2, 10, 1, 0, 0)
# state: obs: (10, 2, 10, 1, 0, 0), done: True, reward: -6.3
# action PASS continue (34.0, 3, 10, 0, 0, 0)
# state: obs: (34.0, 3, 10, 0, 0, 0), done: False, reward: 0.0
# action FIELD_GOAL turnover (24.0, 2, 10, 1, 0, 0)
# state: obs: (24.0, 2, 10, 1, 0, 0), done: True, reward: -5.32
# action PASS continue (25.0, 2, 5.0, 0, 0, 0)
# state: obs: (25.0, 2, 5.0, 0, 0, 0), done: False, reward: 0.0
# action QB_SNEAK continue (33.0, 3, 10, 0, 0, 0)
# state: obs: (33.0, 3, 10, 0, 0, 0), done: False, reward: 0.0
# action PASS continue (33.0, 2, 10.0, 0, 0, 0)
# state: obs: (33.0, 2, 10.0, 0, 0, 0), done: False, reward: 0.0
# action PASS continue (33.0, 1, 10.0, 0, 0, 0)
# state: obs: (33.0, 1, 10.0, 0, 0, 0), done: False, reward: 0.0
# action PASS turnover (33.0, 0, 10.0, 0, 0, 0)
# state: obs: (33.0, 0, 10.0, 0, 0, 0), done: True, reward: -4.6899999999999995
# action RUN continue (16.0, 2, 14.0, 0, 0, 0)
# state: obs: (16.0, 2, 14.0, 0, 0, 0), done: False, reward: 0.0
# action RUN continue (24.0, 1, 6.0, 0, 0, 0)
# state: obs: (24.0, 1, 6.0, 0, 0, 0), done: False, reward: 0.0
# action PASS continue (31.0, 3, 10, 0, 0, 0)
# state: obs: (31.0, 3, 10, 0, 0, 0), done: False, reward: 0.0
# action RUN continue (32.0, 2, 9.0, 0, 0, 0)
# state: obs: (32.0, 2, 9.0, 0, 0, 0), done: False, reward: 0.0
# action QB_SNEAK continue (35.0, 1, 6.0, 0, 0, 0)
# state: obs: (35.0, 1, 6.0, 0, 0, 0), done: False, reward: 0.0
# action PASS continue (47.0, 3, 10, 0, 0, 0)
# state: obs: (47.0, 3, 10, 0, 0, 0), done: False, reward: 0.0
# action QB_SNEAK continue (53.0, 2, 4.0, 0, 0, 0)
# state: obs: (53.0, 2, 4.0, 0, 0, 0), done: False, reward: 0.0
# action PASS continue (84.0, 3, 10, 0, 0, 0)
# state: obs: (84.0, 3, 10, 0, 0, 0), done: False, reward: 0.0
# action RUN continue (93.0, 2, 1.0, 0, 0, 0)
# state: obs: (93.0, 2, 1.0, 0, 0, 0), done: False, reward: 0.0
# action RUN continue (95.0, 3, 5.0, 0, 0, 0)
# state: obs: (95.0, 3, 5.0, 0, 0, 0), done: False, reward: 0.0
# action FIELD_GOAL field goal (95.0, 2, 5.0, 0, 0, 1)
# state: obs: (95.0, 2, 5.0, 0, 0, 1), done: True, reward: 3.0
# action QB_SNEAK continue (22.0, 2, 8.0, 0, 0, 0)
# state: obs: (22.0, 2, 8.0, 0, 0, 0), done: False, reward: 0.0
# action RUN continue (24.0, 1, 6.0, 0, 0, 0)
# state: obs: (24.0, 1, 6.0, 0, 0, 0), done: False, reward: 0.0
# action FIELD_GOAL turnover (14.0, 0, 6.0, 1, 0, 0)
# state: obs: (14.0, 0, 6.0, 1, 0, 0), done: True, reward: -6.02
# action QB_SNEAK continue (35.0, 3, 10, 0, 0, 0)
# state: obs: (35.0, 3, 10, 0, 0, 0), done: False, reward: 0.0
# action PUNT turnover (85.0, 2, 10, 1, 0, 0)
# state: obs: (85.0, 2, 10, 1, 0, 0), done: True, reward: -1.0500000000000003
# action RUN continue (24.0, 2, 6.0, 0, 0, 0)
# state: obs: (24.0, 2, 6.0, 0, 0, 0), done: False, reward: 0.0
# action PASS continue (24.0, 1, 6.0, 0, 0, 0)
# state: obs: (24.0, 1, 6.0, 0, 0, 0), done: False, reward: 0.0
# action PUNT turnover (68.0, 0, 6.0, 1, 0, 0)
# state: obs: (68.0, 0, 6.0, 1, 0, 0), done: True, reward: -2.2399999999999998
# action FIELD_GOAL turnover (10, 2, 10, 1, 0, 0)
# state: obs: (10, 2, 10, 1, 0, 0), done: True, reward: -6.3
# action RUN continue (27.0, 2, 3.0, 0, 0, 0)
# state: obs: (27.0, 2, 3.0, 0, 0, 0), done: False, reward: 0.0
# action QB_SNEAK continue (34.0, 3, 10, 0, 0, 0)
# state: obs: (34.0, 3, 10, 0, 0, 0), done: False, reward: 0.0
# action RUN continue (41.0, 2, 3.0, 0, 0, 0)
# state: obs: (41.0, 2, 3.0, 0, 0, 0), done: False, reward: 0.0
# action QB_SNEAK continue (46.0, 3, 10, 0, 0, 0)
# state: obs: (46.0, 3, 10, 0, 0, 0), done: False, reward: 0.0
# action PASS continue (64.0, 3, 10, 0, 0, 0)
# state: obs: (64.0, 3, 10, 0, 0, 0), done: False, reward: 0.0
# action PUNT turnover (82.0, 2, 10, 1, 0, 0)
# state: obs: (82.0, 2, 10, 1, 0, 0), done: True, reward: -1.2600000000000002
# action PASS continue (31.0, 3, 10, 0, 0, 0)
# state: obs: (31.0, 3, 10, 0, 0, 0), done: False, reward: 0.0
# action RUN continue (34.0, 2, 7.0, 0, 0, 0)
# state: obs: (34.0, 2, 7.0, 0, 0, 0), done: False, reward: 0.0
# action PUNT turnover (80.0, 1, 7.0, 1, 0, 0)
# state: obs: (80.0, 1, 7.0, 1, 0, 0), done: True, reward: -1.3999999999999997
# action RUN continue (24.0, 2, 6.0, 0, 0, 0)
# state: obs: (24.0, 2, 6.0, 0, 0, 0), done: False, reward: 0.0
# action QB_SNEAK continue (34.0, 3, 10, 0, 0, 0)
# state: obs: (34.0, 3, 10, 0, 0, 0), done: False, reward: 0.0
# action PASS continue (34.0, 2, 10.0, 0, 0, 0)
# state: obs: (34.0, 2, 10.0, 0, 0, 0), done: False, reward: 0.0
# action QB_SNEAK continue (44.0, 3, 10, 0, 0, 0)
# state: obs: (44.0, 3, 10, 0, 0, 0), done: False, reward: 0.0
# action PUNT turnover (75.0, 2, 10, 1, 0, 0)
# state: obs: (75.0, 2, 10, 1, 0, 0), done: True, reward: -1.75
# action FIELD_GOAL turnover (10, 2, 10, 1, 0, 0)
# state: obs: (10, 2, 10, 1, 0, 0), done: True, reward: -6.3
# action QB_SNEAK continue (25.0, 2, 5.0, 0, 0, 0)
# state: obs: (25.0, 2, 5.0, 0, 0, 0), done: False, reward: 0.0
# action QB_SNEAK continue (28.0, 1, 2.0, 0, 0, 0)
# state: obs: (28.0, 1, 2.0, 0, 0, 0), done: False, reward: 0.0
# action FIELD_GOAL turnover (18.0, 0, 2.0, 1, 0, 0)
# state: obs: (18.0, 0, 2.0, 1, 0, 0), done: True, reward: -5.74
# action RUN continue (27.0, 2, 3.0, 0, 0, 0)
# state: obs: (27.0, 2, 3.0, 0, 0, 0), done: False, reward: 0.0
# action QB_SNEAK continue (29.0, 1, 1.0, 0, 0, 0)
# state: obs: (29.0, 1, 1.0, 0, 0, 0), done: False, reward: 0.0
# action PUNT turnover (82.0, 0, 1.0, 1, 0, 0)
# state: obs: (82.0, 0, 1.0, 1, 0, 0), done: True, reward: -1.2600000000000002
# action FIELD_GOAL turnover (10, 2, 10, 1, 0, 0)
# state: obs: (10, 2, 10, 1, 0, 0), done: True, reward: -6.3
# action RUN continue (26.0, 2, 4.0, 0, 0, 0)
# state: obs: (26.0, 2, 4.0, 0, 0, 0), done: False, reward: 0.0
# action FIELD_GOAL turnover (16.0, 1, 4.0, 1, 0, 0)
# state: obs: (16.0, 1, 4.0, 1, 0, 0), done: True, reward: -5.88
# action FIELD_GOAL turnover (10, 2, 10, 1, 0, 0)
# state: obs: (10, 2, 10, 1, 0, 0), done: True, reward: -6.3
